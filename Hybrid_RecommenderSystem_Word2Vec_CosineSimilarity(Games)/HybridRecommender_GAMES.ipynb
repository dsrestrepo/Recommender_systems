# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Dataset taken from:
# * https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings?select=Video_Games_Sales_as_at_22_Dec_2016.csv

# %%
games_df = pd.read_csv('./games-dataset/Video_Games_Sales_as_at_22_Dec_2016.csv')
games_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
print('the cols are: ', games_df.shape )
# Out:
# the cols are:  (16719, 16)

# %% [markdown]
# # Data cleaning

# %%
#we don't need the sells so we can drop those columns:
games_df = games_df.drop([ 'Platform', 'Publisher','NA_Sales','EU_Sales', 'JP_Sales', 'Other_Sales', 'Critic_Score','Critic_Count', 'Global_Sales', 'Developer','Rating'], 1)
games_df.head(10)
# Out:
#                         Name  Year_of_Release         Genre User_Score  \
# 0                 Wii Sports           2006.0        Sports          8
# 1          Super Mario Bros.           1985.0      Platform        NaN
# 2             Mario Kart Wii           2008.0        Racing        8.3
# 3          Wii Sports Resort           2009.0        Sports          8
# 4   Pokemon Red/Pokemon Blue           1996.0  Role-Playing        NaN
# 5                     Tetris           1989.0        Puzzle        NaN
# 6      New Super Mario Bros.           2006.0      Platform        8.5
# 7                   Wii Play           2006.0          Misc        6.6
# 8  New Super Mario Bros. Wii           2009.0      Platform        8.4
# 9                  Duck Hunt           1984.0       Shooter        NaN
#
#    User_Count
# 0       322.0
# 1         NaN
# 2       709.0
# 3       192.0
# 4         NaN
# 5         NaN
# 6       431.0
# 7       129.0
# 8       594.0
# 9         NaN

# %%
games_df.rename(columns = {'User_Score':'rating'}, inplace = True)
games_df.rename(columns = {'User_Count':'userId'}, inplace = True)
games_df.rename(columns = {'Name':'title'}, inplace = True)
games_df.rename(columns = {'Genre':'genres'}, inplace = True)
games_df.rename(columns = {'Year_of_Release':'year'}, inplace = True)
games_df.head(10)
# Out:
#                        title    year        genres rating  userId
# 0                 Wii Sports  2006.0        Sports      8   322.0
# 1          Super Mario Bros.  1985.0      Platform    NaN     NaN
# 2             Mario Kart Wii  2008.0        Racing    8.3   709.0
# 3          Wii Sports Resort  2009.0        Sports      8   192.0
# 4   Pokemon Red/Pokemon Blue  1996.0  Role-Playing    NaN     NaN
# 5                     Tetris  1989.0        Puzzle    NaN     NaN
# 6      New Super Mario Bros.  2006.0      Platform    8.5   431.0
# 7                   Wii Play  2006.0          Misc    6.6   129.0
# 8  New Super Mario Bros. Wii  2009.0      Platform    8.4   594.0
# 9                  Duck Hunt  1984.0       Shooter    NaN     NaN

# %%
#See columns with missing Data
cols_with_miss=[col for col in games_df.columns if games_df[col].isnull().any()]
print('the cols missing are: ',cols_with_miss)
#see how many rows are missing in Name, rating and userId:
miss_name = games_df['title'].isnull().sum()
print('the missing in name are: ',miss_name)
miss_rating = games_df['rating'].isnull().sum()
print('the missing ratings are: ',miss_rating)
miss_userid = games_df['userId'].isnull().sum()
print('the missing users are: ', miss_userid)
# Out:
# the cols missing are:  ['title', 'year', 'genres', 'rating', 'userId']
# the missing in name are:  2
# the missing ratings are:  6704
# the missing users are:  9129

# %%
#Delete the clumns without user id
games_df = games_df[pd.notnull(games_df['userId'])]
#see how many rows are missing in Name, rating and userId:
miss_name = games_df['title'].isnull().sum()
print('the missing in name are: ',miss_name)
miss_rating = games_df['rating'].isnull().sum()
print('the missing ratings are: ',miss_rating)
miss_userid = games_df['userId'].isnull().sum()
print('the missing users are: ', miss_userid)
miss_year = games_df['year'].isnull().sum()
print('the missing users are: ', miss_year)
miss_year = games_df['genres'].isnull().sum()
print('the missing genres are: ', miss_year)
games_df.head(10)
# Out:
# the missing in name are:  0
# the missing ratings are:  0
# the missing users are:  0
# the missing users are:  127
# the missing genres are:  0
#                         title    year    genres rating  userId
# 0                  Wii Sports  2006.0    Sports      8   322.0
# 2              Mario Kart Wii  2008.0    Racing    8.3   709.0
# 3           Wii Sports Resort  2009.0    Sports      8   192.0
# 6       New Super Mario Bros.  2006.0  Platform    8.5   431.0
# 7                    Wii Play  2006.0      Misc    6.6   129.0
# 8   New Super Mario Bros. Wii  2009.0  Platform    8.4   594.0
# 11              Mario Kart DS  2005.0    Racing    8.6   464.0
# 13                    Wii Fit  2007.0    Sports    7.7   146.0
# 14         Kinect Adventures!  2010.0      Misc    6.3   106.0
# 15               Wii Fit Plus  2009.0    Sports    7.4    52.0

# %%
#change data tu numeric or categorical
games_df['title'] = games_df['title'].astype('category')
games_df['gameId'] = games_df['title'].cat.codes
games_df['rating'] = pd.to_numeric(games_df['rating'])
games_df['userId'] = pd.to_numeric(games_df['userId'])
games_df['year'] = pd.to_numeric(games_df['year'])
games_df.head()
# Out:
#                    title    year    genres  rating  userId  gameId
# 0             Wii Sports  2006.0    Sports     8.0   322.0    4515
# 2         Mario Kart Wii  2008.0    Racing     8.3   709.0    2254
# 3      Wii Sports Resort  2009.0    Sports     8.0   192.0    4517
# 6  New Super Mario Bros.  2006.0  Platform     8.5   431.0    2759
# 7               Wii Play  2006.0      Misc     6.6   129.0    4513

# %%
#game id to int
games_df['userId'] = games_df['userId'].astype(int)
games_df.head()
# Out:
#                    title    year    genres  rating  userId  gameId
# 0             Wii Sports  2006.0    Sports     8.0     322    4515
# 2         Mario Kart Wii  2008.0    Racing     8.3     709    2254
# 3      Wii Sports Resort  2009.0    Sports     8.0     192    4517
# 6  New Super Mario Bros.  2006.0  Platform     8.5     431    2759
# 7               Wii Play  2006.0      Misc     6.6     129    4513

# %%
#games_df.groupby('gameId')['userId'].count().sort_values(ascending=False).head(20)
#games_df[games_df['userId']== 4.0]
#games_df.groupby('gameId')['userId'].count().sort_values(ascending=False).head(20)

# %%
#games_df[games_df['gameId']== 2732]

# %% [markdown]
# # Content Based

# %%
ratings_df = games_df.copy()
ratings_df.head()
# Out:
#                    title    year    genres  rating  userId  gameId
# 0             Wii Sports  2006.0    Sports     8.0     322    4515
# 2         Mario Kart Wii  2008.0    Racing     8.3     709    2254
# 3      Wii Sports Resort  2009.0    Sports     8.0     192    4517
# 6  New Super Mario Bros.  2006.0  Platform     8.5     431    2759
# 7               Wii Play  2006.0      Misc     6.6     129    4513

# %%
users = ratings_df['userId'].unique().tolist() #take the users
#print(users)

# %%
games_by_user = [] #array of dictionary of games and users
for user in users:
  user_df = ratings_df[ratings_df['userId'] == user] #take the games whatched by the user
  user_df = user_df[['gameId', 'genres']] #take the columns that we need
  user_df = user_df.set_index('gameId') 
  games_by_user.append(user_df.to_dict()) #create the dict game id : genres
#games_by_user

# %%
#the genres title is just noise, so we will remove this and use just the conten of each dictionary
train_list = []
for user_dict in games_by_user:
  train_list.append(user_dict['genres'])
#train_list

# %%
#conver the dictionary to arrays
final_train_list = []
for user_dict in train_list:
  values = []
  for key,value in user_dict.items():
    for genre in value.strip().split(' '):
      values.append(genre)
      values.append(str(int(key)))
  final_train_list.append(values)
final_train_list
# Out:
# [['Sports', '4515'],
#  ['Racing', '2254', 'Action', '1572'],
#  ['Sports', '4517', 'Action', '839', 'Fighting', '2473'],
#  ['Platform', '2759', 'Racing', '1451', 'Shooter', '3699', 'Fighting', '3748'],
#  ['Misc',
#   '4513',
#   'Action',
#   '26',
#   'Fighting',
#   '3593',
#   'Role-Playing',
#   '4382',
#   'Platform',
#   '731',
#   'Role-Playing',
#   '893',
#   'Simulation',
#   '2226'],
#  ['Platform', '2762', 'Racing', '1453'],
#  ['Racing', '2253'],
#  ['Sports',
#   '4507',
#   'Sports',
#   '3020',
#   'Action',
#   '1618',
#   'Action',
#   '689',
#   'Role-Playing',
#   '3039',
#   'Action',
#   '3169'],
#  ['Misc',
#   '1972',
#   'Action',
#   '3620',
#   'Simulation',
#   '148',
#   'Sports',
#   '1287',
#   'Shooter',
#   '3699',
#   'Role-Playing',
#   '2962',
#   'Action',
#   '2058',
#   'Shooter',
#   '3671',
#   'Role-Playing',
#   '1382',
#   'Role-Playing',
#   '1410',
#   'Action',
#   '297',
#   'Sports',
#   '4516',
#   'Action',
#   '139',
#   'Shooter',
#   '3838',
#   'Shooter',
#   '1782',
#   'Action',
#   '3170',
#   'Strategy',
#   '1121',
#   'Strategy',
#   '1240',
#   'Shooter',
#   '1265'],
#  ['Sports',
#   '4508',
#   'Puzzle',
#   '3031',
#   'Adventure',
#   '2826',
#   'Misc',
#   '1667',
#   'Racing',
#   '3196',
#   'Action',
#   '2040',
#   'Misc',
#   '3238',
#   'Adventure',
#   '4630',
#   'Action',
#   '1574',
#   'Adventure',
#   '2320',
#   'Shooter',
#   '1591',
#   'Strategy',
#   '4154',
#   'Sports',
#   '2656',
#   'Action',
#   '1872',
#   'Fighting',
#   '1053',
#   'Role-Playing',
#   '3286',
#   'Shooter',
#   '179',
#   'Shooter',
#   '1176',
#   'Sports',
#   '1296',
#   'Sports',
#   '113',
#   'Shooter',
#   '644',
#   'Role-Playing',
#   '3833',
#   'Sports',
#   '262',
#   'Platform',
#   '3057',
#   'Action',
#   '1924',
#   'Role-Playing',
#   '175',
#   'Action',
#   '2786',
#   'Strategy',
#   '1608',
#   'Role-Playing',
#   '76',
#   'Action',
#   '2059',
#   'Sports',
#   '2566',
#   'Role-Playing',
#   '2288'],
#  ['Action', '1617'],
#  ['Action', '1620', 'Shooter', '105'],
#  ['Misc',
#   '452',
#   'Role-Playing',
#   '2968',
#   'Role-Playing',
#   '1066',
#   'Action',
#   '2971',
#   'Simulation',
#   '3694',
#   'Action',
#   '3970',
#   'Strategy',
#   '3070',
#   'Action',
#   '4230',
#   'Puzzle',
#   '1950',
#   'Action',
#   '3297',
#   'Role-Playing',
#   '1766',
#   'Role-Playing',
#   '1308',
#   'Role-Playing',
#   '991',
#   'Adventure',
#   '119',
#   'Fighting',
#   '1055',
#   'Action',
#   '3949',
#   'Racing',
#   '4383',
#   'Shooter',
#   '777',
#   'Action',
#   '4278',
#   'Adventure',
#   '708',
#   'Action',
#   '1719',
#   'Strategy',
#   '537',
#   'Racing',
#   '667',
#   'Sports',
#   '1286'],
#  ['Action', '1617'],
#  ['Action', '1621'],
#  ['Puzzle',
#   '450',
#   'Sports',
#   '2573',
#   'Misc',
#   '1670',
#   'Platform',
#   '724',
#   'Action',
#   '1775',
#   'Sports',
#   '4586',
#   'Shooter',
#   '4196',
#   'Role-Playing',
#   '2911',
#   'Sports',
#   '2149',
#   'Sports',
#   '4242',
#   'Action',
#   '1718',
#   'Simulation',
#   '185',
#   'Strategy',
#   '1868',
#   'Racing',
#   '2744',
#   'Misc',
#   '769',
#   'Action',
#   '2939',
#   'Shooter',
#   '1962',
#   'Platform',
#   '4476',
#   'Sports',
#   '2175',
#   'Racing',
#   '2552',
#   'Racing',
#   '3097',
#   'Platform',
#   '4019',
#   'Action',
#   '1250',
#   'Sports',
#   '2571',
#   'Platform',
#   '3858',
#   'Fighting',
#   '2074',
#   'Fighting',
#   '1046',
#   'Sports',
#   '4164',
#   'Sports',
#   '2583',
#   'Action',
#   '4491',
#   'Action',
#   '1323',
#   'Misc',
#   '2961',
#   'Simulation',
#   '3378',
#   'Misc',
#   '796',
#   'Role-Playing',
#   '3',
#   'Action',
#   '4398',
#   'Sports',
#   '2620',
#   'Action',
#   '4206',
#   'Action',
#   '3697',
#   'Action',
#   '410',
#   'Action',
#   '1748',
#   'Sports',
#   '1278',
#   'Fighting',
#   '2700',
#   'Sports',
#   '3148',
#   'Action',
#   '3625',
#   'Action',
#   '2870',
#   'Role-Playing',
#   '1462',
#   'Action',
#   '1291',
#   'Shooter',
#   '888',
#   'Sports',
#   '1298',
#   'Action',
#   '1132',
#   'Action',
#   '2479',
#   'Action',
#   '3688',
#   'Racing',
#   '3463',
#   'Fighting',
#   '1418',
#   'Role-Playing',
#   '4042',
#   'Sports',
#   '3776',
#   'Platform',
#   '3119',
#   'Sports',
#   '4557',
#   'Sports',
#   '4243',
#   'Puzzle',
#   '140',
#   'Shooter',
#   '3689',
#   'Action',
#   '1544',
#   'Misc',
#   '1668',
#   'Action',
#   '4410',
#   'Action',
#   '109',
#   'Action',
#   '3099',
#   'Adventure',
#   '3407',
#   'Misc',
#   '3122',
#   'Action',
#   '3014',
#   'Sports',
#   '3736',
#   'Simulation',
#   '817',
#   'Action',
#   '2242',
#   'Fighting',
#   '1306',
#   'Role-Playing',
#   '2798',
#   'Action',
#   '1894',
#   'Sports',
#   '407',
#   'Action',
#   '4481',
#   'Platform',
#   '2716',
#   'Role-Playing',
#   '1997',
#   'Action',
#   '4153',
#   'Role-Playing',
#   '4521',
#   'Role-Playing',
#   '4387',
#   'Racing',
#   '1348',
#   'Simulation',
#   '151',
#   'Sports',
#   '3024',
#   'Action',
#   '1135',
#   'Sports',
#   '1002',
#   'Role-Playing',
#   '1646',
#   'Action',
#   '3005',
#   'Fighting',
#   '392',
#   'Action',
#   '2886',
#   'Shooter',
#   '2356',
#   'Racing',
#   '665',
#   'Misc',
#   '2402',
#   'Sports',
#   '3272',
#   'Strategy',
#   '3824',
#   'Role-Playing',
#   '932',
#   'Role-Playing',
#   '3610',
#   'Simulation',
#   '4078',
#   'Action',
#   '299',
#   'Action',
#   '1579',
#   'Simulation',
#   '1921',
#   'Strategy',
#   '4590',
#   'Sports',
#   '2673',
#   'Shooter',
#   '2691',
#   'Puzzle',
#   '23',
#   'Action',
#   '2042',
#   'Fighting',
#   '1660',
#   'Adventure',
#   '3044',
#   'Shooter',
#   '513',
#   'Strategy',
#   '3510',
#   'Strategy',
#   '1807',
#   'Racing',
#   '4427',
#   'Action',
#   '3013',
#   'Simulation',
#   '123',
#   'Action',
#   '4599',
#   'Strategy',
#   '678',
#   'Action',
#   '4060',
#   'Role-Playing',
#   '3779',
#   'Role-Playing',
#   '2072',
#   'Simulation',
#   '1767',
#   'Puzzle',
#   '3060',
#   'Action',
#   '165'],
#  ['Racing', '1603', 'Action', '4022', 'Action', '4217', 'Shooter', '105'],
#  ['Shooter', '553'],
#  ['Shooter', '547'],
#  ['Shooter', '548'],
#  ['Shooter', '548'],
#  ['Shooter', '552'],
#  ['Shooter', '553'],
#  ['Action', '1615', 'Strategy', '2930'],
#  ['Fighting', '3809'],
#  ['Racing', '2251'],
#  ['Shooter', '547'],
#  ['Action', '1617'],
#  ['Simulation',
#   '150',
#   'Role-Playing',
#   '1027',
#   'Action',
#   '2365',
#   'Action',
#   '4228',
#   'Action',
#   '3159'],
#  ['Shooter', '1696'],
#  ['Racing', '1604', 'Action', '4232'],
#  ['Platform', '3791'],
#  ['Action', '1616'],
#  ['Racing', '1601', 'Sports', '2203', 'Action', '1922'],
#  ['Platform', '3788'],
#  ['Racing', '1605'],
#  ['Shooter', '552'],
#  ['Action', '1616'],
#  ['Shooter', '550'],
#  ['Misc',
#   '1933',
#   'Action',
#   '2033',
#   'Sports',
#   '1794',
#   'Sports',
#   '876',
#   'Sports',
#   '4675',
#   'Sports',
#   '2513',
#   'Action',
#   '2043',
#   'Sports',
#   '2567',
#   'Misc',
#   '1502',
#   'Racing',
#   '41',
#   'Fighting',
#   '507',
#   'Sports',
#   '3388',
#   'Action',
#   '2050',
#   'Misc',
#   '4514',
#   'Sports',
#   '4158',
#   'Action',
#   '2042',
#   'Shooter',
#   '3607',
#   'Action',
#   '4479',
#   'Sports',
#   '2195',
#   'Platform',
#   '2300',
#   'Sports',
#   '2194',
#   'Shooter',
#   '860',
#   'Sports',
#   '2208',
#   'Shooter',
#   '1017',
#   'Platform',
#   '161',
#   'Action',
#   '1872',
#   'Shooter',
#   '2314',
#   'Racing',
#   '42',
#   'Sports',
#   '520',
#   'Simulation',
#   '600',
#   'Sports',
#   '2294',
#   'Simulation',
#   '3372',
#   'Misc',
#   '2402',
#   'Racing',
#   '3632',
#   'Platform',
#   '3117',
#   'Shooter',
#   '3546',
#   'Action',
#   '1145',
#   'Racing',
#   '1801',
#   'Action',
#   '3697',
#   'Action',
#   '370',
#   'Action',
#   '1816',
#   'Platform',
#   '730',
#   'Role-Playing',
#   '1567',
#   'Platform',
#   '1186',
#   'Simulation',
#   '4129',
#   'Sports',
#   '2212',
#   'Fighting',
#   '2710',
#   'Racing',
#   '1421',
#   'Sports',
#   '2667',
#   'Sports',
#   '2176',
#   'Shooter',
#   '3321',
#   'Role-Playing',
#   '2289',
#   'Sports',
#   '2640',
#   'Racing',
#   '726',
#   'Misc',
#   '2266',
#   'Sports',
#   '2600',
#   'Sports',
#   '2581',
#   'Shooter',
#   '179',
#   'Action',
#   '1291',
#   'Action',
#   '3973',
#   'Misc',
#   '2441',
#   'Shooter',
#   '3700',
#   'Adventure',
#   '303',
#   'Role-Playing',
#   '272',
#   'Fighting',
#   '4344',
#   'Racing',
#   '1901',
#   'Sports',
#   '2173',
#   'Role-Playing',
#   '1056',
#   'Sports',
#   '530',
#   'Action',
#   '3629',
#   'Action',
#   '4493',
#   'Fighting',
#   '3946',
#   'Action',
#   '1716',
#   'Role-Playing',
#   '466',
#   'Role-Playing',
#   '3615',
#   'Shooter',
#   '1682',
#   'Shooter',
#   '1754',
#   'Action',
#   '4606',
#   'Action',
#   '1532',
#   'Shooter',
#   '2846',
#   'Sports',
#   '671',
#   'Platform',
#   '2955',
#   'Action',
#   '2355',
#   'Action',
#   '3664',
#   'Simulation',
#   '1768',
#   'Shooter',
#   '4303',
#   'Sports',
#   '2599',
#   'Shooter',
#   '3394',
#   'Shooter',
#   '3602',
#   'Role-Playing',
#   '428',
#   'Misc',
#   '2864',
#   'Shooter',
#   '4056',
#   'Action',
#   '1712',
#   'Action',
#   '4647',
#   'Sports',
#   '2672',
#   'Sports',
#   '3931',
#   'Action',
#   '4220',
#   'Platform',
#   '751',
#   'Fighting',
#   '1656',
#   'Misc',
#   '2935',
#   'Racing',
#   '2540',
#   'Action',
#   '1324',
#   'Action',
#   '3762',
#   'Adventure',
#   '560',
#   'Adventure',
#   '2281',
#   'Action',
#   '3972',
#   'Racing',
#   '4691',
#   'Action',
#   '384',
#   'Racing',
#   '2485',
#   'Action',
#   '881',
#   'Racing',
#   '3250',
#   'Shooter',
#   '1264',
#   'Strategy',
#   '2398',
#   'Fighting',
#   '2283',
#   'Sports',
#   '2229',
#   'Action',
#   '2015',
#   'Strategy',
#   '4596',
#   'Role-Playing',
#   '4190',
#   'Shooter',
#   '3875',
#   'Strategy',
#   '4468',
#   'Action',
#   '1342',
#   'Action',
#   '4254',
#   'Role-Playing',
#   '380',
#   'Platform',
#   '2860',
#   'Shooter',
#   '994',
#   'Action',
#   '1344',
#   'Fighting',
#   '1660',
#   'Action',
#   '3888',
#   'Role-Playing',
#   '4352',
#   'Action',
#   '3738',
#   'Sports',
#   '3737',
#   'Role-Playing',
#   '1247',
#   'Shooter',
#   '2876',
#   'Strategy',
#   '1122',
#   'Adventure',
#   '1000',
#   'Shooter',
#   '2381',
#   'Strategy',
#   '3963'],
#  ['Platform', '2760', 'Action', '3151'],
#  ['Shooter', '1703'],
#  ['Role-Playing', '1387'],
#  ['Shooter', '1698'],
#  ['Racing',
#   '1602',
#   'Shooter',
#   '2314',
#   'Misc',
#   '4512',
#   'Action',
#   '3333',
#   'Fighting',
#   '3591',
#   'Strategy',
#   '3252',
#   'Racing',
#   '3034',
#   'Action',
#   '1107'],
#  ['Misc',
#   '1928',
#   'Simulation',
#   '4086',
#   'Platform',
#   '3458',
#   'Simulation',
#   '4129',
#   'Fighting',
#   '1360',
#   'Action',
#   '962',
#   'Sports',
#   '2618',
#   'Simulation',
#   '2522',
#   'Sports',
#   '2197',
#   'Racing',
#   '668',
#   'Shooter',
#   '4203',
#   'Fighting',
#   '2477',
#   'Sports',
#   '2565',
#   'Simulation',
#   '4077',
#   'Action',
#   '1128',
#   'Racing',
#   '2743',
#   'Fighting',
#   '2478',
#   'Shooter',
#   '4365',
#   'Sports',
#   '2199',
#   'Platform',
#   '3662',
#   'Sports',
#   '4244',
#   'Sports',
#   '2601',
#   'Shooter',
#   '2952',
#   'Action',
#   '729',
#   'Racing',
#   '2185',
#   'Racing',
#   '1916',
#   'Action',
#   '1127',
#   'Role-Playing',
#   '1375',
#   'Racing',
#   '213',
#   'Misc',
#   '1450',
#   'Action',
#   '1213',
#   'Sports',
#   '2229',
#   'Role-Playing',
#   '1783',
#   'Role-Playing',
#   '2327',
#   'Misc',
#   '1632',
#   'Sports',
#   '2580',
#   'Fighting',
#   '2283',
#   'Role-Playing',
#   '1031',
#   'Action',
#   '1135',
#   'Action',
#   '1715',
#   'Action',
#   '4492',
#   'Fighting',
#   '398',
#   'Action',
#   '2854',
#   'Role-Playing',
#   '3864',
#   'Action',
#   '3986',
#   'Role-Playing',
#   '1224',
#   'Role-Playing',
#   '2136',
#   'Fighting',
#   '565',
#   'Action',
#   '3905',
#   'Shooter',
#   '1485',
#   'Shooter',
#   '1179',
#   'Adventure',
#   '2227',
#   'Action',
#   '3903',
#   'Racing',
#   '3383',
#   'Action',
#   '4485',
#   'Action',
#   '3594',
#   'Action',
#   '4314',
#   'Shooter',
#   '3038',
#   'Action',
#   '3951',
#   'Action',
#   '1214',
#   'Misc',
#   '259',
#   'Action',
#   '3351',
#   'Sports',
#   '1167',
#   'Action',
#   '696',
#   'Strategy',
#   '4155',
#   'Action',
#   '870',
#   'Sports',
#   '2670',
#   'Role-Playing',
#   '2834',
#   'Shooter',
#   '2318',
#   'Action',
#   '226',
#   'Role-Playing',
#   '284',
#   'Action',
#   '218',
#   'Adventure',
#   '118',
#   'Racing',
#   '3964',
#   'Shooter',
#   '4378',
#   'Sports',
#   '1283',
#   'Adventure',
#   '1090',
#   'Adventure',
#   '4613',
#   'Simulation',
#   '4080',
#   'Simulation',
#   '89',
#   'Puzzle',
#   '2893',
#   'Strategy',
#   '1843',
#   'Simulation',
#   '3095'],
#  ['Shooter', '550'],
#  ['Shooter', '544'],
#  ['Simulation', '149', 'Shooter', '542'],
#  ['Misc',
#   '2264',
#   'Misc',
#   '778',
#   'Sports',
#   '1279',
#   'Sports',
#   '4692',
#   'Platform',
#   '3637',
#   'Action',
#   '2054',
#   'Fighting',
#   '3876',
#   'Shooter',
#   '3944',
#   'Misc',
#   '2135',
#   'Fighting',
#   '2900',
#   'Fighting',
#   '4347'],
#  ['Role-Playing', '3960'],
#  ['Sports', '1280', 'Shooter', '1015'],
#  ['Shooter', '1694'],
#  ['Misc',
#   '4511',
#   'Platform',
#   '2007',
#   'Sports',
#   '4644',
#   'Racing',
#   '2741',
#   'Platform',
#   '4118',
#   'Action',
#   '3688',
#   'Racing',
#   '1271',
#   'Fighting',
#   '3591',
#   'Action',
#   '1130',
#   'Action',
#   '4350',
#   'Racing',
#   '1270',
#   'Role-Playing',
#   '272',
#   'Role-Playing',
#   '3089',
#   'Sports',
#   '2655',
#   'Shooter',
#   '547',
#   'Misc',
#   '437',
#   'Misc',
#   '3232',
#   'Simulation',
#   '3740',
#   'Action',
#   '1873',
#   'Role-Playing',
#   '4017',
#   'Role-Playing',
#   '3402',
#   'Simulation',
#   '1725',
#   'Fighting',
#   '1032',
#   'Action',
#   '843',
#   'Simulation',
#   '816',
#   'Adventure',
#   '3735',
#   'Shooter',
#   '692'],
#  ['Misc',
#   '2261',
#   'Role-Playing',
#   '1381',
#   'Role-Playing',
#   '2973',
#   'Sports',
#   '2157',
#   'Role-Playing',
#   '1386'],
#  ['Action',
#   '1291',
#   'Role-Playing',
#   '2448',
#   'Platform',
#   '2103',
#   'Action',
#   '2365'],
#  ['Role-Playing', '1389', 'Role-Playing', '921'],
#  ['Simulation', '4089'],
#  ['Role-Playing', '1388'],
#  ['Role-Playing',
#   '2980',
#   'Sports',
#   '1289',
#   'Action',
#   '4028',
#   'Shooter',
#   '325',
#   'Adventure',
#   '2923',
#   'Shooter',
#   '2892',
#   'Role-Playing',
#   '3325'],
#  ['Action', '1619', 'Role-Playing', '621', 'Simulation', '4076'],
#  ['Shooter', '546'],
#  ['Sports', '1281'],
#  ['Platform', '3792'],
#  ['Shooter', '556', 'Sports', '3236', 'Action', '1854'],
#  ['Shooter', '322'],
#  ['Racing',
#   '2735',
#   'Misc',
#   '1677',
#   'Strategy',
#   '3468',
#   'Platform',
#   '589',
#   'Shooter',
#   '316',
#   'Adventure',
#   '1592',
#   'Shooter',
#   '1486'],
#  ['Misc',
#   '1927',
#   'Puzzle',
#   '3368',
#   'Action',
#   '4429',
#   'Sports',
#   '2273',
#   'Sports',
#   '3314',
#   'Racing',
#   '916',
#   'Action',
#   '4037',
#   'Action',
#   '3173',
#   'Action',
#   '4283',
#   'Simulation',
#   '4313',
#   'Shooter',
#   '3548',
#   'Racing',
#   '1095',
#   'Sports',
#   '857',
#   'Strategy',
#   '31'],
#  ['Shooter', '322'],
#  ['Role-Playing', '1313'],
#  ['Fighting', '3892'],
#  ['Action', '4031'],
#  ['Platform', '721', 'Role-Playing', '2121'],
#  ['Racing', '2252'],
#  ['Fighting', '3810', 'Action', '4031'],
#  ['Racing',
#   '2736',
#   'Action',
#   '3019',
#   'Sports',
#   '2197',
#   'Fighting',
#   '3896',
#   'Action',
#   '2065',
#   'Strategy',
#   '1411',
#   'Adventure',
#   '2397',
#   'Shooter',
#   '1016',
#   'Simulation',
#   '833',
#   'Role-Playing',
#   '4014',
#   'Sports',
#   '4241'],
#  ['Misc',
#   '1934',
#   'Misc',
#   '651',
#   'Action',
#   '2043',
#   'Racing',
#   '2730',
#   'Racing',
#   '40',
#   'Racing',
#   '3036',
#   'Platform',
#   '3565',
#   'Role-Playing',
#   '1051',
#   'Sports',
#   '2592',
#   'Action',
#   '4315',
#   'Shooter',
#   '2316',
#   'Platform',
#   '3858',
#   'Adventure',
#   '2521',
#   'Platform',
#   '3622',
#   'Action',
#   '1555',
#   'Sports',
#   '2571',
#   'Simulation',
#   '395',
#   'Simulation',
#   '1737',
#   'Role-Playing',
#   '1367',
#   'Action',
#   '1850',
#   'Role-Playing',
#   '3673',
#   'Sports',
#   '1292',
#   'Platform',
#   '1888',
#   'Action',
#   '3009',
#   'Action',
#   '4228',
#   'Action',
#   '2128',
#   'Action',
#   '1148',
#   'Fighting',
#   '1048',
#   'Action',
#   '1718',
#   'Sports',
#   '4421',
#   'Puzzle',
#   '3919',
#   'Role-Playing',
#   '1866',
#   'Platform',
#   '4020',
#   'Action',
#   '3851',
#   'Shooter',
#   '4210',
#   'Racing',
#   '1273',
#   'Sports',
#   '2610',
#   'Action',
#   '3297',
#   'Adventure',
#   '611',
#   'Role-Playing',
#   '4376',
#   'Action',
#   '384',
#   'Adventure',
#   '1373',
#   'Action',
#   '1138',
#   'Adventure',
#   '3630',
#   'Racing',
#   '2490',
#   'Action',
#   '214',
#   'Racing',
#   '3195',
#   'Misc',
#   '3414',
#   'Role-Playing',
#   '4306',
#   'Adventure',
#   '2028',
#   'Action',
#   '1597',
#   'Fighting',
#   '895',
#   'Fighting',
#   '3281',
#   'Action',
#   '2845',
#   'Simulation',
#   '195',
#   'Sports',
#   '2644',
#   'Shooter',
#   '426',
#   'Fighting',
#   '579',
#   'Action',
#   '196',
#   'Fighting',
#   '389',
#   'Platform',
#   '155',
#   'Shooter',
#   '658',
#   'Shooter',
#   '3186',
#   'Fighting',
#   '2790',
#   'Simulation',
#   '4291',
#   'Simulation',
#   '3860',
#   'Strategy',
#   '4588',
#   'Adventure',
#   '2990'],
#  ['Shooter', '1535'],
#  ['Action', '4354'],
#  ['Shooter', '544'],
#  ['Action', '4353'],
#  ['Misc',
#   '357',
#   'Racing',
#   '2736',
#   'Role-Playing',
#   '2970',
#   'Simulation',
#   '793',
#   'Role-Playing',
#   '1068',
#   'Shooter',
#   '4195',
#   'Platform',
#   '723',
#   'Action',
#   '4073',
#   'Sports',
#   '2619',
#   'Shooter',
#   '4322',
#   'Shooter',
#   '4286',
#   'Racing',
#   '924',
#   'Shooter',
#   '540',
#   'Fighting',
#   '2709',
#   'Sports',
#   '2608',
#   'Sports',
#   '1721',
#   'Sports',
#   '2196',
#   'Sports',
#   '4239',
#   'Platform',
#   '1008',
#   'Action',
#   '2960',
#   'Fighting',
#   '567',
#   'Strategy',
#   '1491',
#   'Action',
#   '2372',
#   'Action',
#   '1713',
#   'Sports',
#   '2625',
#   'Shooter',
#   '1892',
#   'Fighting',
#   '1359',
#   'Fighting',
#   '2720',
#   'Sports',
#   '2554',
#   'Racing',
#   '501',
#   'Sports',
#   '2232',
#   'Action',
#   '2037',
#   'Role-Playing',
#   '763',
#   'Role-Playing',
#   '3834',
#   'Action',
#   '4288',
#   'Shooter',
#   '4198',
#   'Fighting',
#   '3744',
#   'Action',
#   '1715',
#   'Role-Playing',
#   '2938',
#   'Shooter',
#   '3043',
#   'Fighting',
#   '2022',
#   'Shooter',
#   '863',
#   'Action',
#   '142',
#   'Sports',
#   '4433',
#   'Action',
#   '70',
#   'Fighting',
#   '174',
#   'Racing',
#   '3574',
#   'Shooter',
#   '4181',
#   'Racing',
#   '1422',
#   'Fighting',
#   '764',
#   'Shooter',
#   '1183',
#   'Action',
#   '2857',
#   'Action',
#   '877',
#   'Adventure',
#   '2117',
#   'Action',
#   '662',
#   'Fighting',
#   '566',
#   'Sports',
#   '1628',
#   'Racing',
#   '2548',
#   'Role-Playing',
#   '934',
#   'Strategy',
#   '2106',
#   'Fighting',
#   '393',
#   'Shooter',
#   '3422',
#   'Shooter',
#   '276',
#   'Role-Playing',
#   '2116',
#   'Action',
#   '4283',
#   'Action',
#   '1824',
#   'Sports',
#   '3268',
#   'Simulation',
#   '3452',
#   'Shooter',
#   '2837',
#   'Strategy',
#   '3827',
#   'Fighting',
#   '825',
#   'Shooter',
#   '4262',
#   'Racing',
#   '233',
#   'Action',
#   '3335'],
#  ['Action', '3136'],
#  ['Sports', '1278'],
#  ['Action', '222'],
#  ['Platform',
#   '1009',
#   'Sports',
#   '2563',
#   'Action',
#   '868',
#   'Shooter',
#   '4201',
#   'Action',
#   '1336'],
#  ['Shooter', '1701'],
#  ['Role-Playing', '3960'],
#  ['Role-Playing',
#   '2978',
#   'Action',
#   '3167',
#   'Role-Playing',
#   '4571',
#   'Role-Playing',
#   '2089',
#   'Simulation',
#   '4612'],
#  ['Role-Playing',
#   '1986',
#   'Role-Playing',
#   '1028',
#   'Action',
#   '333',
#   'Action',
#   '3160'],
#  ['Shooter', '1697'],
#  ['Action', '3136'],
#  ['Platform', '3795', 'Shooter', '495', 'Action', '2363', 'Adventure', '4034'],
#  ['Role-Playing', '4576'],
#  ['Action',
#   '1097',
#   'Action',
#   '4043',
#   'Sports',
#   '2210',
#   'Action',
#   '1775',
#   'Racing',
#   '2744',
#   'Shooter',
#   '556',
#   'Role-Playing',
#   '2449',
#   'Action',
#   '3266',
#   'Strategy',
#   '4204',
#   'Simulation',
#   '1728',
#   'Role-Playing',
#   '4180',
#   'Shooter',
#   '1206',
#   'Shooter',
#   '3379',
#   'Platform',
#   '2419',
#   'Action',
#   '2423'],
#  ['Shooter', '1536'],
#  ['Sports',
#   '1975',
#   'Simulation',
#   '46',
#   'Platform',
#   '3662',
#   'Fighting',
#   '1361',
#   'Fighting',
#   '1358',
#   'Fighting',
#   '2724',
#   'Shooter',
#   '3984',
#   'Strategy',
#   '59',
#   'Misc',
#   '3231',
#   'Shooter',
#   '4371',
#   'Shooter',
#   '620',
#   'Simulation',
#   '2406',
#   'Fighting',
#   '853',
#   'Role-Playing',
#   '3519',
#   'Simulation',
#   '3485',
#   'Strategy',
#   '629',
#   'Simulation',
#   '3500'],
#  ['Shooter', '1534'],
#  ['Sports', '1279'],
#  ['Action', '2360', 'Platform', '2426'],
#  ['Action', '2359'],
#  ['Action', '2364', 'Shooter', '2892'],
#  ['Role-Playing', '1396'],
#  ['Action', '4008'],
#  ['Platform', '2099'],
#  ['Action', '3157', 'Sports', '2565'],
#  ['Role-Playing', '1067', 'Role-Playing', '3870'],
#  ['Fighting',
#   '3891',
#   'Action',
#   '4214',
#   'Racing',
#   '1093',
#   'Racing',
#   '4536',
#   'Misc',
#   '2888',
#   'Adventure',
#   '1806',
#   'Role-Playing',
#   '3853',
#   'Action',
#   '1777',
#   'Role-Playing',
#   '1119',
#   'Action',
#   '1879',
#   'Shooter',
#   '2123',
#   'Action',
#   '3479',
#   'Sports',
#   '1290'],
#  ['Shooter', '897'],
#  ['Action',
#   '2052',
#   'Action',
#   '2040',
#   'Misc',
#   '3238',
#   'Shooter',
#   '2122',
#   'Action',
#   '1722',
#   'Action',
#   '2213',
#   'Action',
#   '2830',
#   'Action',
#   '3524',
#   'Fighting',
#   '1061',
#   'Platform',
#   '597',
#   'Platform',
#   '369',
#   'Action',
#   '2423',
#   'Fighting',
#   '4416',
#   'Action',
#   '3408',
#   'Racing',
#   '1509',
#   'Action',
#   '3221',
#   'Sports',
#   '2589',
#   'Misc',
#   '2889',
#   'Action',
#   '255'],
#  ['Simulation',
#   '701',
#   'Racing',
#   '2414',
#   'Racing',
#   '3071',
#   'Simulation',
#   '3710',
#   'Sports',
#   '1287',
#   'Racing',
#   '709',
#   'Sports',
#   '3240',
#   'Sports',
#   '4646',
#   'Misc',
#   '1012',
#   'Simulation',
#   '784',
#   'Simulation',
#   '3648',
#   'Sports',
#   '4247',
#   'Sports',
#   '4240',
#   'Adventure',
#   '963',
#   'Action',
#   '2054',
#   'Shooter',
#   '4175',
#   'Sports',
#   '1281',
#   'Role-Playing',
#   '1070',
#   'Action',
#   '1291',
#   'Action',
#   '4041',
#   'Fighting',
#   '4441',
#   'Racing',
#   '1917',
#   'Action',
#   '3370',
#   'Puzzle',
#   '176',
#   'Shooter',
#   '695',
#   'Role-Playing',
#   '2528',
#   'Racing',
#   '1512',
#   'Fighting',
#   '2695',
#   'Sports',
#   '4432',
#   'Fighting',
#   '1047',
#   'Racing',
#   '732',
#   'Misc',
#   '3365',
#   'Sports',
#   '4159',
#   'Role-Playing',
#   '622',
#   'Role-Playing',
#   '1369',
#   'Fighting',
#   '1584',
#   'Misc',
#   '1945',
#   'Action',
#   '3606',
#   'Strategy',
#   '3468',
#   'Action',
#   '26',
#   'Sports',
#   '2161',
#   'Shooter',
#   '4322',
#   'Sports',
#   '4419',
#   'Fighting',
#   '3785',
#   'Action',
#   '4350',
#   'Shooter',
#   '2535',
#   'Fighting',
#   '3889',
#   'Action',
#   '2939',
#   'Fighting',
#   '1360',
#   'Racing',
#   '1981',
#   'Sports',
#   '4234',
#   'Sports',
#   '117',
#   'Role-Playing',
#   '2113',
#   'Role-Playing',
#   '1225',
#   'Action',
#   '2328',
#   'Racing',
#   '1423',
#   'Action',
#   '3005',
#   'Action',
#   '4132',
#   'Action',
#   '1720',
#   'Shooter',
#   '4366',
#   'Action',
#   '2746',
#   'Shooter',
#   '413',
#   'Sports',
#   '3930',
#   'Simulation',
#   '1921',
#   'Fighting',
#   '1864',
#   'Shooter',
#   '129',
#   'Shooter',
#   '827',
#   'Action',
#   '290',
#   'Action',
#   '2025',
#   'Action',
#   '3975',
#   'Action',
#   '2064',
#   'Shooter',
#   '3067',
#   'Platform',
#   '871',
#   'Shooter',
#   '3069',
#   'Action',
#   '2041',
#   'Action',
#   '383',
#   'Adventure',
#   '758',
#   'Racing',
#   '1421',
#   'Sports',
#   '2583',
#   'Role-Playing',
#   '1120',
#   'Adventure',
#   '4179',
#   'Sports',
#   '113',
#   'Role-Playing',
#   '1769',
#   'Puzzle',
#   '2021',
#   'Strategy',
#   '2787',
#   'Sports',
#   '2164',
#   'Action',
#   '1528',
#   'Shooter',
#   '1183',
#   'Shooter',
#   '1923',
#   'Puzzle',
#   '2894',
#   'Sports',
#   '2155',
#   'Adventure',
#   '2125',
#   'Platform',
#   '2345',
#   'Role-Playing',
#   '3214',
#   'Action',
#   '3912',
#   'Platform',
#   '4117',
#   'Strategy',
#   '107',
#   'Puzzle',
#   '750',
#   'Role-Playing',
#   '2835',
#   'Platform',
#   '3115',
#   'Action',
#   '2078',
#   'Shooter',
#   '3981',
#   'Action',
#   '1024',
#   'Adventure',
#   '2471',
#   'Simulation',
#   '2407',
#   'Role-Playing',
#   '3952',
#   'Misc',
#   '2368',
#   'Adventure',
#   '1881',
#   'Action',
#   '605',
#   'Action',
#   '3949',
#   'Strategy',
#   '4145',
#   'Action',
#   '1152'],
#  ['Action', '220'],
#  ['Adventure', '217', 'Platform', '2013'],
#  ['Racing', '1456', 'Shooter', '2308', 'Shooter', '756'],
#  ['Platform',
#   '3790',
#   'Action',
#   '3628',
#   'Action',
#   '1720',
#   'Action',
#   '2050',
#   'Misc',
#   '3571',
#   'Sports',
#   '2593',
#   'Fighting',
#   '884',
#   'Platform',
#   '2000',
#   'Sports',
#   '2194',
#   'Misc',
#   '869',
#   'Sports',
#   '356',
#   'Fighting',
#   '1360',
#   'Sports',
#   '2272',
#   'Fighting',
#   '4440',
#   'Fighting',
#   '4444',
#   'Platform',
#   '3640',
#   'Shooter',
#   '4199',
#   'Sports',
#   '2615',
#   'Shooter',
#   '3685',
#   'Role-Playing',
#   '4605',
#   'Platform',
#   '402',
#   'Fighting',
#   '1039',
#   'Adventure',
#   '4126',
#   'Sports',
#   '2653',
#   'Strategy',
#   '331',
#   'Action',
#   '3008',
#   'Action',
#   '3851',
#   'Action',
#   '3162',
#   'Action',
#   '4220',
#   'Role-Playing',
#   '125',
#   'Adventure',
#   '3511',
#   'Strategy',
#   '79',
#   'Racing',
#   '2490',
#   'Adventure',
#   '2080',
#   'Role-Playing',
#   '3880',
#   'Shooter',
#   '494',
#   'Platform',
#   '3012',
#   'Racing',
#   '3216',
#   'Shooter',
#   '4184',
#   'Shooter',
#   '4200',
#   'Role-Playing',
#   '2240',
#   'Misc',
#   '1742',
#   'Action',
#   '3949',
#   'Action',
#   '1924'],
#  ['Role-Playing',
#   '2451',
#   'Sports',
#   '2270',
#   'Sports',
#   '2204',
#   'Fighting',
#   '3595',
#   'Action',
#   '3411',
#   'Action',
#   '2046',
#   'Puzzle',
#   '4122',
#   'Racing',
#   '3915',
#   'Shooter',
#   '4181'],
#  ['Action', '294'],
#  ['Action', '1617'],
#  ['Racing',
#   '2255',
#   'Sports',
#   '1287',
#   'Sports',
#   '2196',
#   'Misc',
#   '1664',
#   'Platform',
#   '3568',
#   'Racing',
#   '502',
#   'Action',
#   '882',
#   'Misc',
#   '1743',
#   'Role-Playing',
#   '621',
#   'Strategy',
#   '3205'],
#  ['Platform',
#   '724',
#   'Misc',
#   '3230',
#   'Platform',
#   '2004',
#   'Shooter',
#   '4201',
#   'Role-Playing',
#   '3410',
#   'Racing',
#   '1508',
#   'Action',
#   '956'],
#  ['Shooter', '556'],
#  ['Shooter', '4355'],
#  ['Role-Playing', '1398'],
#  ['Role-Playing', '1380', 'Shooter', '1538'],
#  ['Action', '222'],
#  ['Role-Playing', '1391', 'Shooter', '316'],
#  ['Shooter', '546'],
#  ['Action', '220'],
#  ['Sports',
#   '2209',
#   'Role-Playing',
#   '3691',
#   'Action',
#   '839',
#   'Role-Playing',
#   '4328',
#   'Racing',
#   '505',
#   'Misc',
#   '801',
#   'Action',
#   '27'],
#  ['Platform', '2761'],
#  ['Role-Playing', '1073', 'Action', '3004', 'Shooter', '3177'],
#  ['Puzzle',
#   '3029',
#   'Action',
#   '4224',
#   'Fighting',
#   '2287',
#   'Action',
#   '2371',
#   'Shooter',
#   '810',
#   'Role-Playing',
#   '1835'],
#  ['Action', '1291', 'Action', '1926'],
#  ['Role-Playing', '923'],
#  ['Shooter',
#   '2316',
#   'Racing',
#   '2413',
#   'Action',
#   '2560',
#   'Sports',
#   '4430',
#   'Action',
#   '4044',
#   'Action',
#   '2408',
#   'Fighting',
#   '2706',
#   'Shooter',
#   '206',
#   'Shooter',
#   '3508',
#   'Action',
#   '1343',
#   'Action',
#   '1107',
#   'Action',
#   '1116'],
#  ['Misc',
#   '1666',
#   'Action',
#   '1619',
#   'Shooter',
#   '2836',
#   'Action',
#   '3007',
#   'Fighting',
#   '387',
#   'Fighting',
#   '1859',
#   'Action',
#   '3912',
#   'Strategy',
#   '315'],
#  ['Role-Playing', '1303', 'Role-Playing', '3958'],
#  ['Action', '3160', 'Racing', '2734', 'Platform', '4305'],
#  ['Action', '4025'],
#  ['Sports',
#   '1290',
#   'Racing',
#   '728',
#   'Shooter',
#   '543',
#   'Action',
#   '3712',
#   'Shooter',
#   '204',
#   'Strategy',
#   '1750'],
#  ['Action', '3155', 'Platform', '2427'],
#  ['Action',
#   '1622',
#   'Sports',
#   '2563',
#   'Role-Playing',
#   '1589',
#   'Role-Playing',
#   '3675',
#   'Fighting',
#   '3595',
#   'Role-Playing',
#   '947',
#   'Adventure',
#   '3837'],
#  ['Sports',
#   '4236',
#   'Shooter',
#   '549',
#   'Shooter',
#   '540',
#   'Role-Playing',
#   '4604',
#   'Shooter',
#   '3139',
#   'Simulation',
#   '1980',
#   'Racing',
#   '1999',
#   'Action',
#   '228',
#   'Platform',
#   '2802',
#   'Racing',
#   '1093',
#   'Sports',
#   '3240',
#   'Shooter',
#   '479',
#   'Shooter',
#   '4634',
#   'Misc',
#   '1668',
#   'Sports',
#   '1278',
#   'Misc',
#   '1741',
#   'Racing',
#   '2439',
#   'Role-Playing',
#   '3443',
#   'Role-Playing',
#   '953',
#   'Action',
#   '2972',
#   'Role-Playing',
#   '3211'],
#  ['Misc',
#   '1667',
#   'Action',
#   '2052',
#   'Sports',
#   '2207',
#   'Simulation',
#   '4076',
#   'Racing',
#   '732',
#   'Racing',
#   '2178',
#   'Platform',
#   '3557',
#   'Shooter',
#   '3686',
#   'Puzzle',
#   '3808',
#   'Puzzle',
#   '3796',
#   'Fighting',
#   '3743',
#   'Racing',
#   '3573',
#   'Shooter',
#   '1893',
#   'Fighting',
#   '2283',
#   'Action',
#   '2718',
#   'Action',
#   '2243',
#   'Fighting',
#   '4441',
#   'Role-Playing',
#   '2447',
#   'Fighting',
#   '399',
#   'Action',
#   '3363',
#   'Action',
#   '1714',
#   'Shooter',
#   '20',
#   'Action',
#   '588',
#   'Role-Playing',
#   '3284',
#   'Action',
#   '2032',
#   'Action',
#   '2854',
#   'Action',
#   '2821',
#   'Action',
#   '1139',
#   'Fighting',
#   '1061',
#   'Action',
#   '1213',
#   'Role-Playing',
#   '4571',
#   'Action',
#   '1779',
#   'Action',
#   '805',
#   'Shooter',
#   '557',
#   'Shooter',
#   '2422',
#   'Fighting',
#   '3999',
#   'Action',
#   '1620',
#   'Role-Playing',
#   '3326',
#   'Strategy',
#   '2797',
#   'Action',
#   '3697',
#   'Strategy',
#   '331',
#   'Racing',
#   '1276',
#   'Strategy',
#   '330'],
#  ['Shooter',
#   '2091',
#   'Sports',
#   '1285',
#   'Shooter',
#   '2310',
#   'Racing',
#   '2411',
#   'Action',
#   '3968',
#   'Fighting',
#   '4336',
#   'Sports',
#   '1286',
#   'Sports',
#   '3016',
#   'Sports',
#   '2176',
#   'Action',
#   '5',
#   'Simulation',
#   '2304',
#   'Sports',
#   '2632',
#   'Action',
#   '962',
#   'Action',
#   '3171',
#   'Role-Playing',
#   '3772',
#   'Sports',
#   '858',
#   'Role-Playing',
#   '1366',
#   'Role-Playing',
#   '931',
#   'Role-Playing',
#   '3869',
#   'Shooter',
#   '3841',
#   'Sports',
#   '2659',
#   'Fighting',
#   '4447',
#   'Fighting',
#   '2705',
#   'Simulation',
#   '190',
#   'Simulation',
#   '4297',
#   'Fighting',
#   '4449',
#   'Shooter',
#   '875',
#   'Role-Playing',
#   '945',
#   'Role-Playing',
#   '2142',
#   'Shooter',
#   '4302',
#   'Racing',
#   '3190',
#   'Role-Playing',
#   '3438',
#   'Simulation',
#   '2431',
#   'Misc',
#   '781',
#   'Action',
#   '490',
#   'Action',
#   '1188',
#   'Shooter',
#   '2752',
#   'Role-Playing',
#   '246',
#   'Action',
#   '3912',
#   'Action',
#   '4206',
#   'Shooter',
#   '3979'],
#  ['Role-Playing', '1312'],
#  ['Action', '4356'],
#  ['Sports',
#   '2194',
#   'Sports',
#   '4244',
#   'Action',
#   '4214',
#   'Strategy',
#   '2928',
#   'Action',
#   '3713',
#   'Sports',
#   '4430',
#   'Shooter',
#   '2952',
#   'Shooter',
#   '3305',
#   'Shooter',
#   '3145',
#   'Action',
#   '2780',
#   'Action',
#   '4290'],
#  ['Strategy', '3718'],
#  ['Adventure', '217', 'Role-Playing', '1317'],
#  ['Action', '1573'],
#  ['Action',
#   '1099',
#   'Fighting',
#   '1034',
#   'Racing',
#   '2739',
#   'Shooter',
#   '543',
#   'Action',
#   '4339',
#   'Shooter',
#   '3545',
#   'Sports',
#   '2658',
#   'Role-Playing',
#   '930',
#   'Misc',
#   '3726'],
#  ['Action', '294', 'Shooter', '2386'],
#  ['Sports', '4237', 'Shooter', '327'],
#  ['Simulation', '147', 'Shooter', '444', 'Strategy', '87'],
#  ['Action', '4358'],
#  ['Action', '4029'],
#  ['Misc',
#   '1667',
#   'Action',
#   '2052',
#   'Fighting',
#   '2475',
#   'Shooter',
#   '547',
#   'Misc',
#   '1664',
#   'Action',
#   '2008',
#   'Strategy',
#   '3468',
#   'Action',
#   '2047',
#   'Platform',
#   '2005',
#   'Racing',
#   '3916',
#   'Sports',
#   '18',
#   'Sports',
#   '2153',
#   'Role-Playing',
#   '1372',
#   'Action',
#   '3629',
#   'Platform',
#   '595',
#   'Action',
#   '4290',
#   'Misc',
#   '3232',
#   'Shooter',
#   '4320',
#   'Platform',
#   '369',
#   'Action',
#   '3512',
#   'Shooter',
#   '2073',
#   'Strategy',
#   '141',
#   'Adventure',
#   '3729',
#   'Shooter',
#   '2122'],
#  ['Action', '2134', 'Action', '2214', 'Role-Playing', '4249'],
#  ['Racing', '1457'],
#  ['Misc', '1667', 'Action', '4631', 'Action', '1569'],
#  ['Sports',
#   '2195',
#   'Sports',
#   '1154',
#   'Misc',
#   '358',
#   'Sports',
#   '2598',
#   'Racing',
#   '2733',
#   'Sports',
#   '1977',
#   'Sports',
#   '2582',
#   'Sports',
#   '2205',
#   'Shooter',
#   '2312',
#   'Role-Playing',
#   '1052',
#   'Fighting',
#   '2708',
#   'Racing',
#   '2499',
#   'Action',
#   '2041',
#   'Action',
#   '1133',
#   'Sports',
#   '2559',
#   'Fighting',
#   '2702',
#   'Adventure',
#   '643',
#   'Action',
#   '4321',
#   'Action',
#   '2361',
#   'Action',
#   '1040',
#   'Action',
#   '1896',
#   'Misc',
#   '4477',
#   'Action',
#   '4205',
#   'Sports',
#   '4166',
#   'Action',
#   '4228',
#   'Role-Playing',
#   '3287',
#   'Action',
#   '729',
#   'Role-Playing',
#   '1349',
#   'Platform',
#   '2346',
#   'Action',
#   '3475',
#   'Adventure',
#   '1079',
#   'Platform',
#   '590',
#   'Strategy',
#   '4154',
#   'Fighting',
#   '3893',
#   'Shooter',
#   '4221',
#   'Platform',
#   '2010',
#   'Role-Playing',
#   '375',
#   'Fighting',
#   '3992',
#   'Puzzle',
#   '3369',
#   'Adventure',
#   '1852',
#   'Role-Playing',
#   '1211',
#   'Fighting',
#   '386',
#   'Adventure',
#   '2799',
#   'Sports',
#   '3276',
#   'Simulation',
#   '628',
#   'Strategy',
#   '1844',
#   'Sports',
#   '4171',
#   'Action',
#   '571',
#   'Fighting',
#   '1030'],
#  ['Shooter', '1699'],
#  ['Shooter', '551'],
#  ['Action', '1570', 'Shooter', '2988'],
#  ['Shooter', '3633'],
#  ['Misc', '2788'],
#  ['Sports', '4239', 'Platform', '3121', 'Role-Playing', '3588'],
#  ['Sports',
#   '4528',
#   'Action',
#   '1713',
#   'Action',
#   '3721',
#   'Sports',
#   '3314',
#   'Action',
#   '2033',
#   'Action',
#   '3712',
#   'Shooter',
#   '3700',
#   'Platform',
#   '3804',
#   'Platform',
#   '3523',
#   'Misc',
#   '1929',
#   'Sports',
#   '2196',
#   'Role-Playing',
#   '2288',
#   'Racing',
#   '498',
#   'Shooter',
#   '3184',
#   'Simulation',
#   '187',
#   'Sports',
#   '4692',
#   'Sports',
#   '1299',
#   'Fighting',
#   '1058',
#   'Puzzle',
#   '2925',
#   'Fighting',
#   '2721',
#   'Role-Playing',
#   '1234',
#   'Role-Playing',
#   '172',
#   'Action',
#   '1586',
#   'Action',
#   '1189',
#   'Racing',
#   '1272',
#   'Racing',
#   '3098',
#   'Action',
#   '3624',
#   'Shooter',
#   '4320',
#   'Fighting',
#   '2476',
#   'Platform',
#   '3450',
#   'Adventure',
#   '762',
#   'Role-Playing',
#   '2908',
#   'Role-Playing',
#   '1392',
#   'Action',
#   '2511',
#   'Role-Playing',
#   '3403',
#   'Role-Playing',
#   '3850',
#   'Fighting',
#   '3999',
#   'Action',
#   '1714',
#   'Shooter',
#   '3422',
#   'Action',
#   '4003',
#   'Role-Playing',
#   '1609',
#   'Action',
#   '3950'],
#  ['Role-Playing', '3958'],
#  ['Racing',
#   '2740',
#   'Action',
#   '1209',
#   'Simulation',
#   '145',
#   'Fighting',
#   '1035',
#   'Strategy',
#   '2929',
#   'Misc',
#   '3231',
#   'Sports',
#   '3514',
#   'Platform',
#   '3406',
#   'Sports',
#   '3024'],
#  ['Misc',
#   '2402',
#   'Racing',
#   '2409',
#   'Action',
#   '3524',
#   'Fighting',
#   '4440',
#   'Simulation',
#   '4110',
#   'Role-Playing',
#   '1072',
#   'Shooter',
#   '4207',
#   'Simulation',
#   '4089',
#   'Puzzle',
#   '2276',
#   'Action',
#   '4041',
#   'Action',
#   '2051',
#   'Misc',
#   '1665',
#   'Fighting',
#   '4443',
#   'Action',
#   '2048',
#   'Sports',
#   '2148',
#   'Action',
#   '3883',
#   'Racing',
#   '666',
#   'Fighting',
#   '3746',
#   'Role-Playing',
#   '3861',
#   'Shooter',
#   '1552',
#   'Action',
#   '3713',
#   'Role-Playing',
#   '3613',
#   'Fighting',
#   '2482',
#   'Racing',
#   '2745',
#   'Shooter',
#   '4212',
#   'Racing',
#   '3765',
#   'Sports',
#   '4247',
#   'Misc',
#   '2049',
#   'Platform',
#   '2342',
#   'Action',
#   '3798',
#   'Sports',
#   '1287',
#   'Misc',
#   '3233',
#   'Sports',
#   '4255',
#   'Shooter',
#   '2353',
#   'Strategy',
#   '1996',
#   'Racing',
#   '4535',
#   'Role-Playing',
#   '1624',
#   'Strategy',
#   '1125',
#   'Action',
#   '1320',
#   'Platform',
#   '362',
#   'Simulation',
#   '189',
#   'Action',
#   '3007',
#   'Action',
#   '489',
#   'Action',
#   '2569',
#   'Simulation',
#   '191',
#   'Sports',
#   '2665',
#   'Misc',
#   '1503',
#   'Simulation',
#   '156',
#   'Strategy',
#   '1355',
#   'Action',
#   '390',
#   'Shooter',
#   '2073',
#   'Action',
#   '2032',
#   'Shooter',
#   '889',
#   'Role-Playing',
#   '3338',
#   'Shooter',
#   '2382',
#   'Role-Playing',
#   '1365',
#   'Shooter',
#   '3067',
#   'Action',
#   '4482',
#   'Action',
#   '1175',
#   'Action',
#   '3157',
#   'Action',
#   '2245',
#   'Action',
#   '332',
#   'Action',
#   '2044',
#   'Action',
#   '3297',
#   'Role-Playing',
#   '1315',
#   'Simulation',
#   '3255',
#   'Strategy',
#   '1780',
#   'Misc',
#   '3122'],
#  ['Shooter', '546', 'Platform', '3665', 'Action', '224'],
#  ['Shooter', '3178', 'Shooter', '442'],
#  ['Role-Playing', '1989'],
#  ['Platform', '3789'],
#  ['Shooter', '546', 'Action', '2954', 'Action', '868'],
#  ['Sports',
#   '1279',
#   'Platform',
#   '835',
#   'Racing',
#   '1507',
#   'Shooter',
#   '1331',
#   'Fighting',
#   '853',
#   'Role-Playing',
#   '3870',
#   'Role-Playing',
#   '247',
#   'Action',
#   '3370',
#   'Role-Playing',
#   '3775',
#   'Shooter',
#   '559'],
#  ['Role-Playing', '1302'],
#  ['Misc',
#   '2683',
#   'Action',
#   '2040',
#   'Simulation',
#   '792',
#   'Simulation',
#   '794',
#   'Misc',
#   '1740',
#   'Misc',
#   '3503',
#   'Simulation',
#   '3872',
#   'Sports',
#   '2590',
#   'Action',
#   '3199',
#   'Platform',
#   '3637',
#   'Racing',
#   '575',
#   'Action',
#   '3620',
#   'Racing',
#   '4075',
#   'Simulation',
#   '785',
#   'Sports',
#   '2195',
#   'Shooter',
#   '2630',
#   'Sports',
#   '2199',
#   'Sports',
#   '2633',
#   'Sports',
#   '2165',
#   'Racing',
#   '2494',
#   'Action',
#   '3687',
#   'Action',
#   '3415',
#   'Adventure',
#   '4686',
#   'Misc',
#   '2049',
#   'Racing',
#   '2454',
#   'Platform',
#   '4454',
#   'Action',
#   '3643',
#   'Misc',
#   '3923',
#   'Simulation',
#   '4583',
#   'Misc',
#   '1930',
#   'Action',
#   '3973',
#   'Misc',
#   '1674',
#   'Action',
#   '2922',
#   'Action',
#   '347',
#   'Puzzle',
#   '639',
#   'Simulation',
#   '3053',
#   'Puzzle',
#   '747',
#   'Role-Playing',
#   '3865',
#   'Sports',
#   '4239',
#   'Puzzle',
#   '8',
#   'Platform',
#   '2111',
#   'Misc',
#   '58',
#   'Shooter',
#   '2348',
#   'Racing',
#   '576',
#   'Racing',
#   '2414',
#   'Platform',
#   '974',
#   'Racing',
#   '3701',
#   'Puzzle',
#   '4053',
#   'Misc',
#   '2512',
#   'Racing',
#   '3527',
#   'Simulation',
#   '2906',
#   'Action',
#   '1504',
#   'Action',
#   '343',
#   'Action',
#   '1555',
#   'Misc',
#   '2440',
#   'Misc',
#   '965',
#   'Misc',
#   '3301',
#   'Racing',
#   '1918',
#   'Sports',
#   '2642',
#   'Sports',
#   '1439',
#   'Racing',
#   '2456',
#   'Fighting',
#   '2018',
#   'Misc',
#   '886',
#   'Misc',
#   '239',
#   'Action',
#   '3099',
#   'Sports',
#   '2591',
#   'Platform',
#   '1833',
#   'Simulation',
#   '4077',
#   'Sports',
#   '2157',
#   'Action',
#   '2193',
#   'Sports',
#   '526',
#   'Action',
#   '3525',
#   'Platform',
#   '4020',
#   'Sports',
#   '2592',
#   'Sports',
#   '4161',
#   'Platform',
#   '2852',
#   'Racing',
#   '2499',
#   'Sports',
#   '2561',
#   'Racing',
#   '2186',
#   'Sports',
#   '2604',
#   'Fighting',
#   '2076',
#   'Fighting',
#   '2748',
#   'Platform',
#   '3655',
#   'Misc',
#   '2993',
#   'Action',
#   '3927',
#   'Platform',
#   '1477',
#   'Action',
#   '2047',
#   'Platform',
#   '984',
#   'Adventure',
#   '611',
#   'Action',
#   '4377',
#   'Sports',
#   '3931',
#   'Platform',
#   '1180',
#   'Misc',
#   '1675',
#   'Sports',
#   '4248',
#   'Action',
#   '1956',
#   'Misc',
#   '2867',
#   'Action',
#   '1834',
#   'Fighting',
#   '4439',
#   'Strategy',
#   '1108',
#   'Adventure',
#   '3955',
#   'Misc',
#   '2514',
#   'Simulation',
#   '1413',
#   'Simulation',
#   '459',
#   'Sports',
#   '669',
#   'Action',
#   '4051',
#   'Platform',
#   '773',
#   'Sports',
#   '2605',
#   'Action',
#   '1323',
#   'Role-Playing',
#   '2715',
#   'Action',
#   '1716',
#   'Sports',
#   '4556',
#   'Action',
#   '4067',
#   'Sports',
#   '4243',
#   'Adventure',
#   '4061',
#   'Racing',
#   '2731',
#   'Action',
#   '3246',
#   'Action',
#   '2077',
#   'Sports',
#   '1707',
#   'Adventure',
#   '2945',
#   'Sports',
#   '2645',
#   'Action',
#   '3462',
#   'Shooter',
#   '412',
#   'Action',
#   '3904',
#   'Racing',
#   '3298',
#   'Misc',
#   '4641',
#   'Action',
#   '3942',
#   'Sports',
#   '831',
#   'Misc',
#   '1931',
#   'Platform',
#   '3465',
#   'Action',
#   '3627',
#   'Sports',
#   '4293',
#   'Adventure',
#   '429',
#   'Sports',
#   '4159',
#   'Sports',
#   '535',
#   'Shooter',
#   '2535',
#   'Shooter',
#   '4408',
#   'Sports',
#   '520',
#   'Adventure',
#   '2687',
#   'Action',
#   '1809',
#   'Sports',
#   '2197',
#   'Fighting',
#   '4442',
#   'Platform',
#   '3277',
#   'Adventure',
#   '4483',
#   'Sports',
#   '2236',
#   'Platform',
#   '970',
#   'Sports',
#   '2205',
#   'Action',
#   '4553',
#   'Sports',
#   '2538',
#   'Sports',
#   '4567',
#   'Puzzle',
#   '2244',
#   'Sports',
#   '4170',
#   'Shooter',
#   '329',
#   'Sports',
#   '2620',
#   'Misc',
#   '2402',
#   'Puzzle',
#   '3061',
#   'Action',
#   '3355',
#   'Action',
#   '2285',
#   'Action',
#   '3007',
#   'Sports',
#   '115',
#   'Fighting',
#   '3241',
#   'Action',
#   '2347',
#   'Racing',
#   '2189',
#   'Role-Playing',
#   '3778',
#   'Racing',
#   '577',
#   'Action',
#   '3625',
#   'Action',
#   '1505',
#   'Platform',
#   '580',
#   'Sports',
#   '1295',
#   'Sports',
#   '1913',
#   'Fighting',
#   '1584',
#   'Platform',
#   '4173',
#   'Sports',
#   '671',
#   'Strategy',
#   '83',
#   'Racing',
#   '3118',
#   'Action',
#   '3227',
#   'Sports',
#   '3339',
#   'Sports',
#   '2153',
#   'Misc',
#   '614',
#   'Adventure',
#   '618',
#   'Action',
#   '748',
#   'Shooter',
#   '203',
#   'Action',
#   '2697',
#   'Platform',
#   '2989',
#   'Platform',
#   '1845',
#   'Shooter',
#   '3755',
#   'Adventure',
#   '3042',
#   'Puzzle',
#   '3060',
#   'Adventure',
#   '2749',
#   'Puzzle',
#   '435',
#   'Sports',
#   '2235',
#   'Racing',
#   '1353',
#   'Action',
#   '761',
#   'Role-Playing',
#   '4402',
#   'Sports',
#   '529',
#   'Action',
#   '301',
#   'Action',
#   '706',
#   'Action',
#   '3324',
#   'Simulation',
#   '91',
#   'Platform',
#   '4682',
#   'Shooter',
#   '3981',
#   'Misc',
#   '4317',
#   'Misc',
#   '1945',
#   'Action',
#   '3657',
#   'Sports',
#   '2403',
#   'Puzzle',
#   '509',
#   'Action',
#   '4610',
#   'Misc',
#   '1318',
#   'Action',
#   '4037',
#   'Puzzle',
#   '1249',
#   'Fighting',
#   '1257',
#   'Platform',
#   '3928',
#   'Action',
#   '4398',
#   'Adventure',
#   '2525',
#   'Action',
#   '3243',
#   'Puzzle',
#   '1729',
#   'Action',
#   '2996',
#   'Strategy',
#   '3303',
#   'Racing',
#   '2536',
#   'Strategy',
#   '1562',
#   'Racing',
#   '3616',
#   'Sports',
#   '2097',
#   'Role-Playing',
#   '1447',
#   'Adventure',
#   '4267',
#   'Sports',
#   '2084',
#   'Misc',
#   '4133',
#   'Action',
#   '4411',
#   'Action',
#   '3624',
#   'Action',
#   '1448',
#   'Misc',
#   '3231',
#   'Action',
#   '2050',
#   'Adventure',
#   '4172',
#   'Role-Playing',
#   '4541',
#   'Action',
#   '568',
#   'Action',
#   '1759',
#   'Platform',
#   '873',
#   'Adventure',
#   '74',
#   'Action',
#   '3400',
#   'Action',
#   '4261',
#   'Strategy',
#   '2796',
#   'Racing',
#   '360',
#   'Action',
#   '1720',
#   'Simulation',
#   '188',
#   'Misc',
#   '4559',
#   'Adventure',
#   '2126',
#   'Misc',
#   '711',
#   'Simulation',
#   '981',
#   'Simulation',
#   '776',
#   'Racing',
#   '3539',
#   'Strategy',
#   '4600',
#   'Misc',
#   '126',
#   'Action',
#   '1894',
#   'Strategy',
#   '3068',
#   'Adventure',
#   '515',
#   'Adventure',
#   '3373',
#   'Action',
#   '742',
#   'Sports',
#   '3147',
#   'Strategy',
#   '1501',
#   'Simulation',
#   '2987',
#   'Strategy',
#   '4592',
#   'Action',
#   '4222',
#   'Action',
#   '1543',
#   'Misc',
#   '2505',
#   'Platform',
#   '4403',
#   'Sports',
#   '966',
#   'Adventure',
#   '1463',
#   'Action',
#   '4531',
#   'Puzzle',
#   '430',
#   'Action',
#   '3341',
#   'Role-Playing',
#   '3472',
#   'Role-Playing',
#   '212',
#   'Misc',
#   '4676',
#   'Puzzle',
#   '2863',
#   'Sports',
#   '16',
#   'Racing',
#   '667',
#   'Sports',
#   '4552',
#   'Misc',
#   '257',
#   'Shooter',
#   '4177',
#   'Sports',
#   '2984',
#   'Sports',
#   '3101',
#   'Adventure',
#   '2246',
#   'Puzzle',
#   '488',
#   'Adventure',
#   '3265',
#   'Racing',
#   '3848',
#   'Strategy',
#   '775',
#   'Action',
#   '3313',
#   'Sports',
#   '2849',
#   'Platform',
#   '3819',
#   'Strategy',
#   '4591',
#   'Misc',
#   '3052',
#   'Shooter',
#   '4323',
#   'Adventure',
#   '516',
#   'Sports',
#   '1299',
#   'Misc',
#   '1932',
#   'Role-Playing',
#   '2457',
#   'Racing',
#   '3849',
#   'Action',
#   '2895',
#   'Sports',
#   '3104',
#   'Platform',
#   '1181',
#   'Platform',
#   '4260',
#   'Role-Playing',
#   '467',
#   'Sports',
#   '3418',
#   'Action',
#   '2682',
#   'Platform',
#   '2011',
#   'Puzzle',
#   '1793',
#   'Puzzle',
#   '249',
#   'Racing',
#   '3084',
#   'Adventure',
#   '3837',
#   'Platform',
#   '3057',
#   'Action',
#   '1902',
#   'Sports',
#   '2651',
#   'Strategy',
#   '80',
#   'Racing',
#   '1952',
#   'Adventure',
#   '2220',
#   'Fighting',
#   '3667',
#   'Racing',
#   '3654',
#   'Platform',
#   '1186',
#   'Platform',
#   '1548',
#   'Strategy',
#   '1230',
#   'Simulation',
#   '1469',
#   'Racing',
#   '3964',
#   'Misc',
#   '4693',
#   'Sports',
#   '2669',
#   'Strategy',
#   '1566',
#   'Action',
#   '355',
#   'Misc',
#   '2832',
#   'Puzzle',
#   '1644',
#   'Racing',
#   '1466',
#   'Racing',
#   '3191',
#   'Racing',
#   '1611',
#   'Puzzle',
#   '439'],
#  ['Action', '293'],
#  ['Action', '2362'],
#  ['Action', '230', 'Role-Playing', '3959'],
#  ['Role-Playing', '1313'],
#  ['Sports', '1278', 'Racing', '504'],
#  ['Misc',
#   '1252',
#   'Simulation',
#   '4114',
#   'Action',
#   '2033',
#   'Action',
#   '3988',
#   'Shooter',
#   '4195',
#   'Sports',
#   '3420',
#   'Sports',
#   '2564',
#   'Sports',
#   '1155',
#   'Shooter',
#   '549',
#   'Sports',
#   '4237',
#   'Racing',
#   '2549',
#   'Fighting',
#   '1049',
#   'Action',
#   '1811',
#   'Sports',
#   '2568',
#   'Racing',
#   '1260',
#   'Sports',
#   '4160',
#   'Sports',
#   '1162',
#   'Simulation',
#   '47',
#   'Sports',
#   '1288',
#   'Sports',
#   '2198',
#   'Misc',
#   '770',
#   'Simulation',
#   '1723',
#   'Sports',
#   '1285',
#   'Puzzle',
#   '1086',
#   'Platform',
#   '724',
#   'Racing',
#   '2740',
#   'Strategy',
#   '1484',
#   'Platform',
#   '4330',
#   'Racing',
#   '2438',
#   'Action',
#   '2825',
#   'Misc',
#   '3399',
#   'Sports',
#   '2195',
#   'Fighting',
#   '1360',
#   'Action',
#   '4493',
#   'Action',
#   '1213',
#   'Sports',
#   '2230',
#   'Simulation',
#   '4076',
#   'Action',
#   '210',
#   'Strategy',
#   '1958',
#   'Action',
#   '729',
#   'Action',
#   '3349',
#   'Platform',
#   '1823',
#   'Adventure',
#   '2963',
#   'Action',
#   '3521',
#   'Racing',
#   '916',
#   'Sports',
#   '524',
#   'Strategy',
#   '4597',
#   'Action',
#   '1137',
#   'Action',
#   '221',
#   'Role-Playing',
#   '4520',
#   'Misc',
#   '1668',
#   'Racing',
#   '1276',
#   'Racing',
#   '1274',
#   'Action',
#   '1505',
#   'Sports',
#   '1167',
#   'Action',
#   '3987',
#   'Action',
#   '2213',
#   'Platform',
#   '2344',
#   'Role-Playing',
#   '2222',
#   'Strategy',
#   '4310',
#   'Role-Playing',
#   '3782',
#   'Misc',
#   '3934',
#   'Strategy',
#   '1561',
#   'Shooter',
#   '692',
#   'Action',
#   '2905',
#   'Fighting',
#   '1356',
#   'Action',
#   '1310',
#   'Action',
#   '3009',
#   'Role-Playing',
#   '2915',
#   'Action',
#   '4153',
#   'Shooter',
#   '2381',
#   'Role-Playing',
#   '271',
#   'Action',
#   '937',
#   'Action',
#   '1140',
#   'Shooter',
#   '862',
#   'Platform',
#   '159',
#   'Strategy',
#   '4590',
#   'Platform',
#   '4426',
#   'Misc',
#   '1742',
#   'Sports',
#   '1284',
#   'Action',
#   '3153',
#   'Role-Playing',
#   '1883',
#   'Action',
#   '382',
#   'Fighting',
#   '4348',
#   'Racing',
#   '1642',
#   'Action',
#   '1556',
#   'Role-Playing',
#   '3807',
#   'Puzzle',
#   '3586',
#   'Action',
#   '1177',
#   'Shooter',
#   '371',
#   'Adventure',
#   '1173',
#   'Racing',
#   '3918',
#   'Sports',
#   '4275',
#   'Strategy',
#   '3739',
#   'Action',
#   '3908',
#   'Simulation',
#   '674',
#   'Racing',
#   '3843'],
#  ['Racing',
#   '1606',
#   'Sports',
#   '2200',
#   'Role-Playing',
#   '2288',
#   'Fighting',
#   '3591',
#   'Action',
#   '3010',
#   'Platform',
#   '3406',
#   'Action',
#   '4321',
#   'Action',
#   '3007',
#   'Role-Playing',
#   '242'],
#  ['Action', '230'],
#  ['Fighting', '3747', 'Action', '3167'],
#  ['Sports',
#   '2208',
#   'Sports',
#   '4560',
#   'Racing',
#   '3193',
#   'Action',
#   '2616',
#   'Racing',
#   '1269',
#   'Action',
#   '2037',
#   'Sports',
#   '4431',
#   'Shooter',
#   '377',
#   'Action',
#   '3525',
#   'Role-Playing',
#   '4328',
#   'Shooter',
#   '321',
#   'Shooter',
#   '4183',
#   'Simulation',
#   '4665',
#   'Fighting',
#   '391',
#   'Shooter',
#   '327',
#   'Role-Playing',
#   '4648',
#   'Action',
#   '3605',
#   'Sports',
#   '3271',
#   'Platform',
#   '3121',
#   'Sports',
#   '3022',
#   'Sports',
#   '3270',
#   'Sports',
#   '2565',
#   'Shooter',
#   '2752',
#   'Racing',
#   '1273'],
#  ['Shooter', '1691'],
#  ['Role-Playing', '4580'],
#  ['Shooter', '317'],
#  ['Sports',
#   '4563',
#   'Simulation',
#   '704',
#   'Sports',
#   '2609',
#   'Shooter',
#   '2314',
#   'Action',
#   '3345',
#   'Racing',
#   '3913',
#   'Sports',
#   '1905',
#   'Sports',
#   '1295',
#   'Racing',
#   '4191',
#   'Misc',
#   '770',
#   'Sports',
#   '2610',
#   'Sports',
#   '1294',
#   'Action',
#   '348',
#   'Fighting',
#   '1583',
#   'Fighting',
#   '1364',
#   'Action',
#   '3909',
#   'Sports',
#   '4164',
#   'Action',
#   '4043',
#   'Shooter',
#   '3183',
#   'Platform',
#   '730',
#   'Shooter',
#   '478',
#   'Fighting',
#   '401',
#   'Sports',
#   '2666',
#   'Simulation',
#   '2437',
#   'Fighting',
#   '2074',
#   'Action',
#   '1714',
#   'Sports',
#   '484',
#   'Sports',
#   '1281',
#   'Simulation',
#   '2462',
#   'Simulation',
#   '2305',
#   'Strategy',
#   '3825',
#   'Action',
#   '1586',
#   'Strategy',
#   '141',
#   'Action',
#   '2652',
#   'Racing',
#   '499',
#   'Action',
#   '1613',
#   'Racing',
#   '3917',
#   'Shooter',
#   '1467',
#   'Action',
#   '4119',
#   'Action',
#   '3040',
#   'Role-Playing',
#   '3550',
#   'Role-Playing',
#   '2913',
#   'Sports',
#   '1278',
#   'Action',
#   '4120',
#   'Racing',
#   '2491',
#   'Platform',
#   '3459',
#   'Sports',
#   '2651',
#   'Simulation',
#   '1861',
#   'Action',
#   '1417',
#   'Strategy',
#   '1995',
#   'Platform',
#   '4682',
#   'Adventure',
#   '1540',
#   'Sports',
#   '1774',
#   'Shooter',
#   '1488',
#   'Adventure',
#   '3373',
#   'Simulation',
#   '1338',
#   'Action',
#   '1633',
#   'Action',
#   '868',
#   'Shooter',
#   '664',
#   'Simulation',
#   '2729',
#   'Racing',
#   '3215',
#   'Role-Playing',
#   '288',
#   'Fighting',
#   '929',
#   'Action',
#   '207',
#   'Role-Playing',
#   '2016',
#   'Platform',
#   '3529',
#   'Adventure',
#   '472',
#   'Role-Playing',
#   '104',
#   'Role-Playing',
#   '1316',
#   'Action',
#   '836',
#   'Platform',
#   '4654',
#   'Strategy',
#   '2882',
#   'Role-Playing',
#   '3929',
#   'Action',
#   '612',
#   'Platform',
#   '4685'],
#  ['Racing', '1455'],
#  ['Misc',
#   '572',
#   'Sports',
#   '2594',
#   'Puzzle',
#   '3920',
#   'Fighting',
#   '851',
#   'Platform',
#   '641',
#   'Sports',
#   '2572',
#   'Role-Playing',
#   '3677',
#   'Shooter',
#   '2317',
#   'Action',
#   '6',
#   'Sports',
#   '2610',
#   'Action',
#   '2044',
#   'Platform',
#   '3660',
#   'Racing',
#   '3916',
#   'Sports',
#   '2194',
#   'Sports',
#   '4243',
#   'Action',
#   '3206',
#   'Sports',
#   '4159',
#   'Platform',
#   '4475',
#   'Action',
#   '2336',
#   'Platform',
#   '2108',
#   'Platform',
#   '2331',
#   'Action',
#   '2051',
#   'Action',
#   '2652',
#   'Simulation',
#   '1732',
#   'Sports',
#   '3317',
#   'Role-Playing',
#   '3288',
#   'Action',
#   '2041',
#   'Fighting',
#   '2706',
#   'Action',
#   '4396',
#   'Role-Playing',
#   '245',
#   'Role-Playing',
#   '284',
#   'Role-Playing',
#   '687',
#   'Action',
#   '1820',
#   'Strategy',
#   '927',
#   'Action',
#   '1568',
#   'Action',
#   '3158',
#   'Action',
#   '1745',
#   'Fighting',
#   '1032',
#   'Shooter',
#   '2953',
#   'Fighting',
#   '1909',
#   'Role-Playing',
#   '3585',
#   'Strategy',
#   '4071',
#   'Racing',
#   '1511',
#   'Strategy',
#   '3760',
#   'Racing',
#   '665'],
#  ['Action', '4488'],
#  ['Fighting',
#   '3898',
#   'Misc',
#   '2265',
#   'Action',
#   '1062',
#   'Role-Playing',
#   '1221',
#   'Role-Playing',
#   '121',
#   'Shooter',
#   '3001',
#   'Shooter',
#   '4184',
#   'Simulation',
#   '4102'],
# ...
#   '3943',
#   'Misc',
#   '4678',
#   'Role-Playing',
#   '1201',
#   'Simulation',
#   '1733',
#   'Action',
#   '568',
#   'Adventure',
#   '120',
#   'Shooter',
#   '1808',
#   'Shooter',
#   '4662',
#   'Adventure',
#   '952',
#   'Shooter',
#   '777',
#   'Strategy',
#   '4614',
#   'Simulation',
#   '3486',
#   'Adventure',
#   '3282',
#   'Simulation',
#   '4086',
#   'Strategy',
#   '2986'],
#  ['Shooter', '547'],
#  ['Action', '2046', 'Action', '3480', 'Sports', '1430'],
#  ['Shooter', '897', 'Action', '3126'],
#  ['Shooter', '3090', 'Adventure', '101'],
#  ['Action',
#   '1925',
#   'Action',
#   '1988',
#   'Action',
#   '4545',
#   'Action',
#   '3151',
#   'Shooter',
#   '3547'],
#  ['Action', '3473', 'Shooter', '3508', 'Shooter', '320', 'Strategy', '1784'],
#  ['Role-Playing', '920'],
#  ['Fighting',
#   '3593',
#   'Sports',
#   '1158',
#   'Sports',
#   '2660',
#   'Adventure',
#   '101',
#   'Adventure',
#   '996'],
#  ['Platform', '3568', 'Racing', '3916'],
#  ['Misc',
#   '2256',
#   'Fighting',
#   '2474',
#   'Racing',
#   '503',
#   'Shooter',
#   '2390',
#   'Sports',
#   '1157',
#   'Shooter',
#   '3709'],
#  ['Action', '911'],
#  ['Action', '844'],
#  ['Action', '4488', 'Platform', '1010'],
#  ['Shooter', '4544', 'Role-Playing', '4136'],
#  ['Strategy', '4462'],
#  ['Shooter', '4198', 'Action', '1963'],
#  ['Shooter', '4357'],
#  ['Action', '955'],
#  ['Shooter', '548'],
#  ['Action',
#   '3174',
#   'Racing',
#   '917',
#   'Role-Playing',
#   '4006',
#   'Role-Playing',
#   '3285'],
#  ['Shooter', '847'],
#  ['Sports', '1432', 'Platform', '4116', 'Action', '3961'],
#  ['Role-Playing', '2764'],
#  ['Action', '842', 'Role-Playing', '0', 'Action', '222', 'Shooter', '1694'],
#  ['Action', '295', 'Action', '848', 'Role-Playing', '3679'],
#  ['Shooter',
#   '941',
#   'Role-Playing',
#   '462',
#   'Shooter',
#   '1263',
#   'Fighting',
#   '1032',
#   'Shooter',
#   '2838'],
#  ['Shooter', '3176'],
#  ['Action', '545'],
#  ['Shooter', '4201'],
#  ['Fighting', '1360', 'Role-Playing', '3867'],
#  ['Shooter',
#   '325',
#   'Role-Playing',
#   '2770',
#   'Fighting',
#   '4437',
#   'Strategy',
#   '3824'],
#  ['Shooter', '1781', 'Role-Playing', '1119', 'Role-Playing', '1113'],
#  ['Role-Playing', '2291'],
#  ['Action',
#   '962',
#   'Misc',
#   '1671',
#   'Adventure',
#   '45',
#   'Sports',
#   '1284',
#   'Sports',
#   '2658',
#   'Shooter',
#   '2953',
#   'Sports',
#   '2156',
#   'Shooter',
#   '321',
#   'Action',
#   '300',
#   'Role-Playing',
#   '3432',
#   'Action',
#   '2905',
#   'Shooter',
#   '3940',
#   'Shooter',
#   '368',
#   'Role-Playing',
#   '1567',
#   'Role-Playing',
#   '2726',
#   'Strategy',
#   '3703'],
#  ['Strategy', '152'],
#  ['Shooter', '365', 'Action', '2215'],
#  ['Role-Playing', '2292'],
#  ['Simulation', '3494', 'Simulation', '3493'],
#  ['Shooter', '847', 'Role-Playing', '4578'],
#  ['Action', '2358'],
#  ['Action', '2319'],
#  ['Action', '846', 'Shooter', '495'],
#  ['Racing', '1452'],
#  ['Fighting', '1859', 'Platform', '2426', 'Action', '231'],
#  ['Action', '3292'],
#  ['Adventure', '3208'],
#  ['Shooter', '903', 'Strategy', '3470', 'Role-Playing', '905'],
#  ['Role-Playing',
#   '1397',
#   'Racing',
#   '2732',
#   'Role-Playing',
#   '1',
#   'Platform',
#   '4329',
#   'Action',
#   '3172',
#   'Action',
#   '4127',
#   'Action',
#   '3970',
#   'Sports',
#   '2657',
#   'Role-Playing',
#   '4042',
#   'Action',
#   '497',
#   'Sports',
#   '2582',
#   'Sports',
#   '3316',
#   'Action',
#   '2293',
#   'Action',
#   '843',
#   'Role-Playing',
#   '3834',
#   'Role-Playing',
#   '1727',
#   'Strategy',
#   '2951',
#   'Role-Playing',
#   '1201',
#   'Action',
#   '3634',
#   'Racing',
#   '3085',
#   'Action',
#   '2370',
#   'Fighting',
#   '2899',
#   'Racing',
#   '918',
#   'Shooter',
#   '690',
#   'Action',
#   '3966',
#   'Action',
#   '1174',
#   'Strategy',
#   '712'],
#  ['Shooter', '903'],
#  ['Action',
#   '2746',
#   'Action',
#   '4218',
#   'Misc',
#   '1668',
#   'Action',
#   '4290',
#   'Action',
#   '3563',
#   'Strategy',
#   '2951',
#   'Action',
#   '4289',
#   'Sports',
#   '1281'],
#  ['Shooter', '4186'],
#  ['Action', '2408'],
#  ['Racing', '2500', 'Action', '223', 'Action', '231'],
#  ['Shooter', '323'],
#  ['Action', '2396'],
#  ['Action', '753'],
#  ['Shooter', '4211'],
#  ['Shooter', '2124', 'Fighting', '2703'],
#  ['Action', '96', 'Shooter', '110'],
#  ['Action', '1618', 'Role-Playing', '1171', 'Platform', '3454'],
#  ['Role-Playing', '4582'],
#  ['Shooter', '3090', 'Action', '911'],
#  ['Role-Playing', '4138'],
#  ['Action', '4680'],
#  ['Platform', '4640', 'Role-Playing', '1998'],
#  ['Action', '225', 'Shooter', '316'],
#  ['Action', '753'],
#  ['Action', '1124', 'Racing', '2745', 'Role-Playing', '4185'],
#  ['Role-Playing', '1313'],
#  ['Platform', '596', 'Shooter', '443', 'Action', '2358'],
#  ['Role-Playing', '812'],
#  ['Action', '2365'],
#  ['Role-Playing', '4388', 'Racing', '917', 'Racing', '3192'],
#  ['Role-Playing', '1390', 'Action', '4488', 'Action', '867', 'Racing', '1103'],
#  ['Racing', '2734', 'Adventure', '2086', 'Racing', '2497'],
#  ['Action',
#   '4232',
#   'Simulation',
#   '4077',
#   'Racing',
#   '917',
#   'Role-Playing',
#   '2115',
#   'Sports',
#   '2671'],
#  ['Action', '3334', 'Shooter', '1111', 'Strategy', '153'],
#  ['Shooter',
#   '3308',
#   'Role-Playing',
#   '1390',
#   'Fighting',
#   '852',
#   'Shooter',
#   '557'],
#  ['Shooter', '374', 'Action', '1336', 'Sports', '3236'],
#  ['Action', '4680', 'Shooter', '3142'],
#  ['Action',
#   '2778',
#   'Shooter',
#   '2353',
#   'Sports',
#   '1157',
#   'Action',
#   '2779',
#   'Action',
#   '1107',
#   'Shooter',
#   '3397'],
#  ['Action', '1822', 'Shooter', '3672'],
#  ['Role-Playing', '3868', 'Action', '592', 'Action', '3528'],
#  ['Simulation', '1377', 'Sports', '4431', 'Puzzle', '2384'],
#  ['Platform', '3531', 'Action', '2793', 'Strategy', '4310'],
#  ['Sports',
#   '4432',
#   'Shooter',
#   '3142',
#   'Action',
#   '592',
#   'Role-Playing',
#   '1083',
#   'Action',
#   '4649'],
#  ['Fighting',
#   '2702',
#   'Platform',
#   '3579',
#   'Platform',
#   '3530',
#   'Racing',
#   '1103',
#   'Shooter',
#   '445',
#   'Action',
#   '2508',
#   'Sports',
#   '2562',
#   'Shooter',
#   '481',
#   'Simulation',
#   '1827'],
#  ['Puzzle', '570'],
#  ['Shooter', '899'],
#  ['Fighting', '1859', 'Platform', '2419', 'Shooter', '558'],
#  ['Action', '1617'],
#  ['Role-Playing', '1317'],
#  ['Strategy', '3647'],
#  ['Platform', '2426', 'Sports', '1278', 'Action', '1824'],
#  ['Role-Playing', '1384', 'Platform', '3121', 'Platform', '3579'],
#  ['Action', '2319'],
#  ['Shooter', '544'],
#  ['Action', '3409'],
#  ['Shooter', '3784', 'Shooter', '317'],
#  ['Action', '4489', 'Shooter', '3940'],
#  ['Shooter', '105'],
#  ['Role-Playing', '1326', 'Platform', '3121'],
#  ['Role-Playing', '2902'],
#  ['Shooter', '717'],
#  ['Action', '1026'],
#  ['Fighting', '1061'],
#  ['Platform', '2036', 'Role-Playing', '4143', 'Action', '913'],
#  ['Racing', '3034', 'Role-Playing', '3597'],
#  ['Strategy', '1200'],
#  ['Action', '805', 'Role-Playing', '1468'],
#  ['Role-Playing', '2089'],
#  ['Shooter',
#   '4057',
#   'Shooter',
#   '2392',
#   'Action',
#   '3719',
#   'Platform',
#   '3879',
#   'Action',
#   '3167',
#   'Adventure',
#   '4656'],
#  ['Action', '497'],
#  ['Shooter', '108'],
#  ['Role-Playing', '922'],
#  ['Simulation', '4473', 'Sports', '2563', 'Strategy', '892'],
#  ['Racing', '1454', 'Role-Playing', '4506', 'Strategy', '4070'],
#  ['Action', '3528'],
#  ['Shooter', '108', 'Shooter', '470', 'Action', '2367'],
#  ['Shooter', '470'],
#  ['Action', '4032'],
#  ['Action', '4224', 'Action', '4225'],
#  ['Action', '2781'],
#  ['Platform', '3120', 'Racing', '2740'],
#  ['Fighting', '2975', 'Shooter', '3141'],
#  ['Action', '1577', 'Adventure', '2375', 'Action', '1400'],
#  ['Shooter', '1747'],
#  ['Role-Playing', '811'],
#  ['Role-Playing', '3862', 'Shooter', '1243'],
#  ['Role-Playing', '1312'],
#  ['Action', '1620'],
#  ['Strategy',
#   '1406',
#   'Fighting',
#   '987',
#   'Sports',
#   '1976',
#   'Platform',
#   '3570',
#   'Action',
#   '1963',
#   'Sports',
#   '3023',
#   'Adventure',
#   '3937',
#   'Adventure',
#   '75'],
#  ['Role-Playing', '2292'],
#  ['Shooter', '1330'],
#  ['Shooter', '1243'],
#  ['Action', '848'],
#  ['Action', '4137'],
#  ['Action', '2954'],
#  ['Action', '3021'],
#  ['Action', '4632', 'Fighting', '3749', 'Racing', '423'],
#  ['Shooter', '1966'],
#  ['Shooter', '3668', 'Racing', '2731', 'Shooter', '1207'],
#  ['Action', '496', 'Shooter', '3690'],
#  ['Role-Playing', '1027', 'Shooter', '445'],
#  ['Action', '222'],
#  ['Shooter', '443'],
#  ['Action', '805', 'Strategy', '3756', 'Shooter', '3320'],
#  ['Role-Playing', '4622'],
#  ['Fighting', '3748', 'Strategy', '4614'],
#  ['Action', '1926', 'Sports', '3314', 'Strategy', '82', 'Shooter', '2952'],
#  ['Shooter', '754'],
#  ['Action', '4137'],
#  ['Role-Playing', '3959'],
#  ['Shooter', '552'],
#  ['Action', '3169', 'Shooter', '4544'],
#  ['Action', '1616'],
#  ['Shooter', '444', 'Role-Playing', '1529'],
#  ['Role-Playing', '1998'],
#  ['Action',
#   '2102',
#   'Action',
#   '2367',
#   'Platform',
#   '3120',
#   'Action',
#   '2854',
#   'Role-Playing',
#   '1118'],
#  ['Shooter', '481', 'Role-Playing', '4123'],
#  ['Fighting', '3899', 'Action', '3961'],
#  ['Action', '821'],
#  ['Role-Playing', '4623'],
#  ['Shooter', '1111', 'Action', '821'],
#  ['Fighting', '3749', 'Action', '3477', 'Racing', '4538'],
#  ['Action', '1026'],
#  ['Shooter', '553'],
#  ['Role-Playing', '3442'],
#  ['Action',
#   '912',
#   'Role-Playing',
#   '1858',
#   'Racing',
#   '4301',
#   'Role-Playing',
#   '1984'],
#  ['Shooter', '1970'],
#  ['Action', '993'],
#  ['Role-Playing', '1077', 'Shooter', '3548'],
#  ['Sports', '3023'],
#  ['Shooter', '110'],
#  ['Action', '334'],
#  ['Shooter', '2988'],
#  ['Shooter', '4187'],
#  ['Action', '2367'],
#  ['Sports', '3022'],
#  ['Role-Playing', '812', 'Adventure', '3208'],
#  ['Action', '230'],
#  ['Action', '753'],
#  ['Role-Playing', '1027'],
#  ['Strategy', '4264'],
#  ['Role-Playing',
#   '2903',
#   'Racing',
#   '423',
#   'Shooter',
#   '4360',
#   'Action',
#   '238',
#   'Shooter',
#   '3508',
#   'Platform',
#   '700'],
#  ['Sports', '2156'],
#  ['Role-Playing', '4138'],
#  ['Shooter', '326'],
#  ['Strategy', '4615'],
#  ['Shooter', '752'],
#  ['Action', '3476', 'Role-Playing', '3869', 'Role-Playing', '4328'],
#  ['Adventure', '598'],
#  ['Shooter', '2952'],
#  ['Racing', '2734', 'Sports', '2587', 'Role-Playing', '905'],
#  ['Role-Playing', '3075'],
#  ['Role-Playing', '2290'],
#  ['Action', '3961'],
#  ['Strategy', '2694'],
#  ['Platform', '3120'],
#  ['Shooter', '367'],
#  ['Action', '2109', 'Role-Playing', '4605', 'Strategy', '4038'],
#  ['Action', '224'],
#  ['Sports', '1434', 'Strategy', '3509'],
#  ['Action', '956', 'Strategy', '3733'],
#  ['Action', '1026'],
#  ['Shooter', '1331'],
#  ['Shooter', '4131'],
#  ['Role-Playing', '3440', 'Strategy', '4615', 'Sports', '1280'],
#  ['Action', '2811', 'Shooter', '318'],
#  ['Strategy', '4615', 'Strategy', '4039'],
#  ['Action', '2215', 'Strategy', '3204'],
#  ['Shooter', '2952', 'Action', '2792', 'Adventure', '4141'],
#  ['Shooter', '2395'],
#  ['Shooter', '4400'],
#  ['Adventure', '3878'],
#  ['Shooter', '110', 'Action', '1208', 'Strategy', '4463'],
#  ['Action', '2811', 'Platform', '3049', 'Platform', '3559', 'Action', '4066'],
#  ['Strategy', '4265'],
#  ['Action', '846'],
#  ['Action', '229'],
#  ['Shooter', '903'],
#  ['Adventure', '101', 'Shooter', '2892'],
#  ['Role-Playing', '3430'],
#  ['Platform', '3120', 'Action', '2508'],
#  ['Shooter', '4187', 'Shooter', '4542'],
#  ['Shooter', '887', 'Racing', '2732'],
#  ['Shooter', '3947'],
#  ['Shooter', '4186'],
#  ['Shooter', '4467'],
#  ['Action', '1629'],
#  ['Action', '3065'],
#  ['Action', '3170', 'Shooter', '1782', 'Shooter', '2875'],
#  ['Action', '232'],
#  ['Action', '220'],
#  ['Platform', '3532'],
#  ['Shooter', '3608', 'Strategy', '3757'],
#  ['Shooter', '2386', 'Simulation', '4313'],
#  ['Action', '1408', 'Action', '4066'],
#  ['Shooter', '2858'],
#  ['Strategy', '3717'],
#  ['Action', '294'],
#  ['Role-Playing',
#   '1027',
#   'Misc',
#   '803',
#   'Strategy',
#   '4465',
#   'Strategy',
#   '684',
#   'Action',
#   '3836'],
#  ['Role-Playing', '2115'],
#  ['Platform', '2002'],
#  ['Shooter', '4131', 'Shooter', '3953', 'Racing', '918'],
#  ['Role-Playing', '1028'],
#  ['Action', '1329'],
#  ['Action', '2109'],
#  ['Action', '4581'],
#  ['Strategy', '4464'],
#  ['Action', '3483', 'Action', '1346'],
#  ['Simulation', '1435', 'Misc', '3037', 'Action', '1340'],
#  ['Action', '4488'],
#  ['Action', '993'],
#  ['Shooter', '2298'],
#  ['Platform', '3120'],
#  ['Racing', '4301', 'Action', '4229'],
#  ['Action', '2387'],
#  ['Shooter', '3608', 'Action', '820'],
#  ['Role-Playing', '3844'],
#  ['Shooter', '4223'],
#  ['Shooter', '365'],
#  ['Shooter', '546'],
#  ['Shooter', '1111'],
#  ['Adventure', '2086', 'Action', '4219'],
#  ['Action', '4142'],
#  ['Sports', '1278', 'Action', '839'],
#  ['Action', '2214'],
#  ['Role-Playing', '2291'],
#  ['Role-Playing', '813'],
#  ['Platform', '3570'],
#  ['Strategy', '62', 'Action', '3888', 'Racing', '2744'],
#  ['Action', '3481'],
#  ['Action', '3336'],
#  ['Strategy', '78', 'Role-Playing', '1595'],
#  ['Racing', '2738', 'Strategy', '4266'],
#  ['Shooter', '3090'],
#  ['Shooter', '368', 'Shooter', '2123', 'Shooter', '1016'],
#  ['Sports', '3236'],
#  ['Action', '2746', 'Action', '4545'],
#  ['Strategy', '3471'],
#  ['Shooter', '2063'],
#  ['Action', '2408'],
#  ['Platform', '2427'],
#  ['Shooter', '550'],
#  ['Strategy', '683'],
#  ['Platform', '3120', 'Racing', '3192', 'Action', '3007', 'Shooter', '644'],
#  ['Action', '2319'],
#  ['Role-Playing', '4139'],
#  ['Shooter', '847'],
#  ['Action', '3480', 'Role-Playing', '38'],
#  ['Action', '293'],
#  ['Role-Playing', '1303'],
#  ['Action', '296', 'Role-Playing', '4487'],
#  ['Adventure', '598', 'Action', '821', 'Action', '1630'],
#  ['Action', '3562'],
#  ['Role-Playing', '1998'],
#  ['Simulation', '4077', 'Role-Playing', '3209'],
#  ['Shooter', '4575'],
#  ['Action', '3961', 'Shooter', '556'],
#  ['Strategy', '3254'],
#  ['Strategy', '4311'],
#  ['Action', '3169'],
#  ['Shooter', '206'],
#  ['Role-Playing', '3958'],
#  ['Racing', '2734'],
#  ['Adventure', '2030'],
#  ['Action', '1776'],
#  ['Shooter', '1781'],
#  ['Role-Playing', '766'],
#  ['Shooter', '4211'],
#  ['Shooter', '3608'],
#  ['Role-Playing', '3210'],
#  ['Action', '837'],
#  ['Shooter', '3698'],
#  ['Adventure', '1914'],
#  ['Shooter', '887'],
#  ['Shooter', '4467'],
#  ['Action', '1124'],
#  ['Action', '593', 'Action', '1777'],
#  ['Action', '848'],
#  ['Shooter', '108'],
#  ['Role-Playing', '447'],
#  ['Strategy', '3825'],
#  ['Role-Playing', '3597'],
#  ['Action', '2387'],
#  ['Shooter', '1243'],
#  ['Action', '4217'],
#  ['Action',
#   '364',
#   'Simulation',
#   '1471',
#   'Strategy',
#   '4593',
#   'Shooter',
#   '4213'],
#  ['Action', '3334'],
#  ['Action', '4044', 'Role-Playing', '930'],
#  ['Shooter', '442'],
#  ['Shooter', '470'],
#  ['Role-Playing', '812'],
#  ['Role-Playing', '4068'],
#  ['Strategy', '3467'],
#  ['Role-Playing', '4523'],
#  ['Shooter', '1263'],
#  ['Action', '821'],
#  ['Action', '820'],
#  ['Action', '3912'],
#  ['Shooter', '182'],
#  ['Simulation', '631'],
#  ['Shooter', '4057'],
#  ['Role-Playing', '3706'],
#  ['Shooter', '3954'],
#  ['Shooter', '327'],
#  ['Shooter', '3144'],
#  ['Action', '1229'],
#  ['Strategy', '4461'],
#  ['Action', '295'],
#  ['Fighting', '3747', 'Racing', '916'],
#  ['Racing', '3034'],
#  ['Action', '1925'],
#  ['Action', '3528'],
#  ['Action', '710'],
#  ['Adventure', '2188'],
#  ['Platform', '3568', 'Platform', '3121'],
#  ['Shooter', '183'],
#  ['Action', '3021', 'Action', '593'],
#  ['Strategy', '3263'],
#  ['Strategy', '2322'],
#  ['Strategy', '77'],
#  ['Role-Playing', '3211'],
#  ['Strategy', '86'],
#  ['Shooter', '714'],
#  ['Strategy', '3702', 'Role-Playing', '4006'],
#  ['Shooter', '319'],
#  ['Shooter', '4187', 'Action', '4304'],
#  ['Simulation', '4602'],
#  ['Action', '2367'],
#  ['Shooter', '3395'],
#  ['Racing', '2736'],
#  ['Role-Playing', '4259'],
#  ['Role-Playing', '813'],
#  ['Role-Playing', '1305'],
#  ['Action', '96'],
#  ['Racing', '1508'],
#  ['Platform', '2427'],
#  ['Shooter', '3294', 'Role-Playing', '2219'],
#  ['Shooter', '3296'],
#  ['Action', '3151'],
#  ['Action', '2508'],
#  ['Fighting', '2474'],
#  ['Strategy', '2951'],
#  ['Strategy', '3715', 'Role-Playing', '2948'],
#  ['Shooter', '1328'],
#  ['Strategy', '682'],
#  ['Adventure', '2086'],
#  ['Shooter', '3161'],
#  ['Strategy', '1765'],
#  ['Action', '3169'],
#  ['Action', '1621'],
#  ['Action', '593'],
#  ['Shooter', '1701'],
#  ['Action', '3333'],
#  ['Puzzle', '4572'],
#  ['Simulation', '2105'],
#  ['Shooter', '1014'],
#  ['Role-Playing', '2115'],
#  ['Platform', '449'],
#  ['Adventure', '446'],
#  ['Shooter', '2297'],
#  ['Action', '497', 'Racing', '1509'],
#  ['Role-Playing', '4469', 'Role-Playing', '1758'],
#  ['Shooter', '2062'],
#  ['Adventure', '1852'],
#  ['Shooter', '3063'],
#  ['Shooter', '2296'],
#  ['Role-Playing', '2931'],
#  ['Role-Playing', '992'],
#  ['Shooter', '4370'],
#  ['Shooter', '1534'],
#  ['Action', '1615'],
#  ['Strategy', '1786'],
#  ['Role-Playing', '902'],
#  ['Action', '2365']]

# %%
from gensim.test.utils import common_texts
from gensim.models.word2vec import Word2Vec

# %%
#create the model
model = Word2Vec(final_train_list, window=5, min_count=1, workers=4)

# %%
#function that returns similar games
def most_similar_game(game_Id):
    print("Similar of "+ratings_df[ratings_df['gameId'] == int(game_Id)].iloc[0]['title'])
    return [(int(x[0]), ratings_df[ratings_df['gameId'] == int(x[0])].iloc[0]['title']) for x in model.wv.most_similar(game_Id)]

# %%
most_similar_game('4515')
# Out:
# Similar of Wii Sports
# [(3714, 'Star Wars: The Old Republic'),
#  (683, 'Company of Heroes 2'),
#  (1649, 'Guild Wars 2'),
#  (2342, 'Mega Man Zero'),
#  (3441, 'Shin Megami Tensei: Persona 3 Portable'),
#  (813, 'Dark Souls III'),
#  (87, 'Age of Mythology: The Titans'),
#  (1966, 'Killzone'),
#  (2362, 'Metal Gear Solid 3: Snake Eater'),
#  (4372, 'Until Dawn')]

# %%
def most_similar_gener(genres):
  count = 0
  for genre in genres:
    if count == 0:
      vector = model[genre]
      count = count + 1
    else:
      vector = model[genre] + vector
  print("Similar of ",list(genres))
  resp = []
  for x in model.wv.most_similar([vector], topn=30):
    try:
      int(x[0])
      resp.append((int(x[0]), ratings_df[ratings_df['gameId'] == int(x[0])].iloc[0]['title']))
    except:
      print(x)
  return resp

# %%
most_similar_gener(['Action'])
# Out:
# Similar of  ['Action']
# ('Action', 0.9999999403953552)
# ('Sports', 0.9999697804450989)
# ('Misc', 0.9999632835388184)
# ('Simulation', 0.999962568283081)
# ('Shooter', 0.9999610781669617)
# ('Racing', 0.9999604225158691)
# ('Role-Playing', 0.999955415725708)
# ('Platform', 0.9999542236328125)
# ('Fighting', 0.9999536871910095)
# ('Adventure', 0.999945878982544)
# ('Strategy', 0.9999420642852783)
# ('Puzzle', 0.9999325275421143)
# C:\Users\EQUIPO\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# [(1717, 'Harry Potter and the Half-Blood Prince'),
#  (141, 'Angry Birds Star Wars'),
#  (1716, 'Harry Potter and the Goblet of Fire'),
#  (1872, 'Iron Man'),
#  (2047, "LEGO Marvel's Avengers"),
#  (2046, 'LEGO Marvel Super Heroes'),
#  (1504, 'G-Force'),
#  (1590, 'GoldenEye: Rogue Agent'),
#  (3106, 'Ratatouille'),
#  (3912, 'Terraria'),
#  (2078, 'Lego Batman 3: Beyond Gotham'),
#  (2079, 'Lego Star Wars: The Force Awakens'),
#  (1829, 'IL-2 Sturmovik: Birds of Prey'),
#  (1720, "Harry Potter and the Sorcerer's Stone"),
#  (4434, 'WWE All Stars'),
#  (4086, 'The Sims 2: Pets'),
#  (2195, 'Madden NFL 07'),
#  (2196, 'Madden NFL 08')]

# %% [markdown]
# ## Content Based Integration

# %%
#get the genres of the game
def get_genres(game_id):
    return ratings_df[ratings_df['gameId'] == game_id].genres.iloc[0].strip()
print(get_genres(2078))
# Out:
# Action

# %%
def content_based(game_id):
    
    #search by simmilar game
    try:
        game_sim = most_similar_movie(game_id)
    except:
        game_sim = []
        
    #search by simmilar genres
    genres_string = get_genres(int(game_id)) #take the genres of the game
    genres = genres_string.split()
    #print(genres)
    #use the function
    try:
        genres_sim = most_similar_gener(genres)
    except:
        genres_sim = []
    set_1 = set(game_sim)
    set_2 = set(genres_sim)
    gamesSet2_notin_Set1 = list(set_2 - set_1)
    combined_sim = game_sim + gamesSet2_notin_Set1
    #don't repeat game
    combined_similar_games = list(set(combined_sim))
    return combined_similar_games

# %%
content_based('4515')
# Out:
# Similar of Wii Sports
# Similar of  ['Sports']
# ('Sports', 0.9999999403953552)
# ('Action', 0.9999699592590332)
# ('Fighting', 0.9999641180038452)
# ('Racing', 0.9999638795852661)
# ('Adventure', 0.9999621510505676)
# ('Role-Playing', 0.9999605417251587)
# ('Simulation', 0.9999598264694214)
# ('Shooter', 0.9999552965164185)
# ('Misc', 0.9999549984931946)
# ('Platform', 0.9999474883079529)
# ('Strategy', 0.9999400973320007)
# ('Puzzle', 0.9999264478683472)
# C:\Users\EQUIPO\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# [(813, 'Dark Souls III'),
#  (683, 'Company of Heroes 2'),
#  (4434, 'WWE All Stars'),
#  (87, 'Age of Mythology: The Titans'),
#  (1504, 'G-Force'),
#  (1649, 'Guild Wars 2'),
#  (1829, 'IL-2 Sturmovik: Birds of Prey'),
#  (2046, 'LEGO Marvel Super Heroes'),
#  (1590, 'GoldenEye: Rogue Agent'),
#  (2078, 'Lego Batman 3: Beyond Gotham'),
#  (141, 'Angry Birds Star Wars'),
#  (1717, 'Harry Potter and the Half-Blood Prince'),
#  (1872, 'Iron Man'),
#  (1720, "Harry Potter and the Sorcerer's Stone"),
#  (2362, 'Metal Gear Solid 3: Snake Eater'),
#  (4086, 'The Sims 2: Pets'),
#  (3912, 'Terraria'),
#  (3441, 'Shin Megami Tensei: Persona 3 Portable'),
#  (2079, 'Lego Star Wars: The Force Awakens'),
#  (2047, "LEGO Marvel's Avengers"),
#  (2196, 'Madden NFL 08'),
#  (3714, 'Star Wars: The Old Republic'),
#  (2342, 'Mega Man Zero'),
#  (4372, 'Until Dawn'),
#  (3106, 'Ratatouille'),
#  (1289, 'FIFA Soccer 10'),
#  (1716, 'Harry Potter and the Goblet of Fire'),
#  (1966, 'Killzone')]

# %% [markdown]
# # Collaborative Filter

# %%
def add_user(user, games_df):
    #add titles
    titles = user['gameId'].tolist()
    titles = [games_df[games_df['gameId'] == title]['title'].iloc[0].strip() for title in titles]
    user['title'] = titles
    #add user id
    user_id = games_df['userId'].max()+1
    user['userId'] = user_id
    games_df = games_df.append(user, ignore_index = True)
    return user, games_df

# %%
def get_collaborative_filtering(user):
    #to keep the original df
    movies_df = games_df.copy()
    
    if isinstance(user, int):
        user = movies_df[movies_df['userId'] == user]
        
    else:
        #take the dict user, create a dataframe os user and add the dataframe to movies_df
        user, movies_df = add_user(user, movies_df)
    users_with_movies_common = {}
    users = movies_df['userId'].unique().tolist() #take the users

    for user_ in users:
      user_df = movies_df[movies_df['userId'] == user_] #take the games whatched by the user
      user_df = user_df[['gameId', 'userId']] #take the columns that we need
      user_movies_common = user_df[user_df['gameId'].isin(user['gameId'].tolist())]
      users_with_movies_common[user_df['userId'].iloc[0]] = len(user_movies_common)  #create the dict game id : genres

    users_with2=[]
    for user_id,number_movies in users_with_movies_common.items():
        if number_movies >= 1:
            users_with2.append(user_id)
    users_with2 = pd.DataFrame(users_with2, columns=['userId'])
    #users that saw 3 common games or more
    movies_df = movies_df[movies_df['userId'].isin(users_with2['userId'].tolist())]
    #creating the user-item interaction matrix
    movie_matrix_UII = movies_df.pivot_table(index='gameId', columns='userId', values='rating')
    #take my user
    myUser = movies_df['userId'].max()
    #Take the column of the user we want
    myUser = movie_matrix_UII[myUser]
    #calculate the correlation
    similar_to_user = movie_matrix_UII.corrwith(myUser)
    #create the data frame
    corr_user = pd.DataFrame(similar_to_user, columns=['Correlation'])
    #drop the na
    corr_user.dropna(inplace=True)
    #drop the user:
    myUserId = movies_df['userId'].max()
    #corr_user = corr_user.drop([myUserId]) 
    #Most rated games
    corr_user['Correlation'] = corr_user['Correlation']
    corr_user = corr_user.sort_values('Correlation', ascending=False)
    #take just the most correlated
    corr_user = corr_user[0:10]
    #take from movies_df just the games with highest correlation
    movies_df = movies_df[movies_df['userId'].isin(corr_user.index.values.tolist())]
    #add the correlation column to the dataframe
    movies_df['Correlation'] = movies_df['userId'].apply(lambda x: corr_user['Correlation'].loc[x])
    #calculate the weight with the rating
    movies_df['weight'] = (movies_df['rating']*movies_df['Correlation'])/10
    #sort by weight
    movies_df = movies_df.sort_values('weight', ascending=False)
    #take the top games:
    colaborative_filter_df=movies_df[['gameId','title']][0:10]
    #give the format to the games
    colaborative_movies = colaborative_filter_df['gameId'].unique().tolist()
    colaborative_filter_movies = []
    for game in colaborative_movies:
        game = int(game)
        colaborative_filter_movies.append((game,colaborative_filter_df[colaborative_filter_df['gameId'] == game]['title'].iloc[0]))
    return colaborative_filter_movies

# %%
prediction = get_collaborative_filtering(4)
prediction
# Out:
# C:\Users\EQUIPO\anaconda3\lib\site-packages\numpy\lib\function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\EQUIPO\anaconda3\lib\site-packages\numpy\lib\function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# [(4007, 'The Last Story'),
#  (3560, 'Sonic Adventure 2 Battle'),
#  (364, 'Binary Domain'),
#  (4030, 'The Legend of Zelda: Tri Force Heroes'),
#  (4478, 'WarioWare: Smooth Moves'),
#  (4679, '[Prototype 2]'),
#  (2202, 'Madden NFL 13')]

# %%
#ratings_df[ratings_df['title']=='Mortal Kombat vs. DC Universe'][['gameId','title']]
user2=[
    {'gameId': 3159, 'rating':10 },
    {'gameId': 2195, 'rating':6.5 },
    {'gameId': 2740, 'rating':8.5 },
    {'gameId': 141, 'rating':6 },
    {'gameId': 1291, 'rating':8 },
    {'gameId': 2050, 'rating':7 },
    {'gameId': 4003, 'rating':6.5 },
    {'gameId': 1279, 'rating':8 },
    {'gameId': 1278, 'rating':8.5 },
    {'gameId': 2078, 'rating':7.5 },
    {'gameId': 2044, 'rating':6 },
    {'gameId': 2046, 'rating':7.5 },
    {'gameId': 3912, 'rating':6.5 },
    {'gameId': 2043, 'rating':6 },
    {'gameId': 2731, 'rating':9 },
    {'gameId': 3622, 'rating':5.5 },
    {'gameId': 2047, 'rating':8.7 },
    {'gameId': 2732, 'rating':8.9 },
    {'gameId': 3024, 'rating':7.3 },
    {'gameId': 2738, 'rating':8.0 },
    {'gameId': 217, 'rating':10 },
    {'gameId': 2475,'rating':7.5 }
]
user2= pd.DataFrame(user2)

# %%
prediction = get_collaborative_filtering(user2)
prediction
# Out:
# [(217, "Assassin's Creed"),
#  (3159, 'Resident Evil 4'),
#  (1635, "Greg Hastings' Tournament Paintball"),
#  (4129, 'The Urbz: Sims in the City'),
#  (2740, 'Need for Speed: Most Wanted'),
#  (4562, 'World Soccer Winning Eleven 8 International'),
#  (2929, 'Pikmin 2'),
#  (4597, 'Worms: Open Warfare 2'),
#  (524, "Cabela's Dangerous Hunts")]

# %% [markdown]
# # Hybrid recommendation system

# %%
def get_hybrid_recommendation(user,game):
    game = str(game)
    content_based_movies = content_based(game)
    
    #to keep the original df
    movies_df = games_df.copy()
    #take user:
    if isinstance(user, int):
        user_inst = movies_df[movies_df['userId'] == user]
        if len(user_inst.index) > 6:
            collaborative_filter_movies = get_collaborative_filtering(user)
            #add the content_based and collaborative games
            set_1 = set(content_based_movies)
            set_2 = set(collaborative_filter_movies)
            moviesSet2_notin_Set1 = list(set_2 - set_1)
            combined_sim = content_based_movies + moviesSet2_notin_Set1
            #don't repeat games
            combined_similar_movies = list(set(combined_sim))
            #if the list has more then 10 games just the first 10
            if len(combined_similar_movies)>21:
                return combined_similar_movies[0:20]
            
            return combined_similar_movies
    if len(user.index) > 6:
        collaborative_filter_movies = get_collaborative_filtering(user)
        #add the content_based and collaborative games
        set_1 = set(content_based_movies)
        set_2 = set(collaborative_filter_movies)
        moviesSet2_notin_Set1 = list(set_2 - set_1)
        combined_sim = content_based_movies + moviesSet2_notin_Set1
        #don't repeat movies
        combined_similar_movies = list(set(combined_sim))
        #if the list has more then 10 games just the first 10
        
        if len(combined_similar_movies)>21:
            return combined_similar_movies[0:20]
        return combined_similar_movies
        
    #if the list has more then 10 games just the first 10
    
    if len(content_based_movies)>21:
        return content_based_movies[0:20]
    
    #if not enougth games, just return the content based games
    return content_based_movies

# %% [markdown]
# # see Hybrid recommendations

# %%
get_hybrid_recommendation(user2,'4515')
# Out:
# Similar of Wii Sports
# Similar of  ['Sports']
# ('Sports', 0.9999999403953552)
# ('Action', 0.9999699592590332)
# ('Fighting', 0.9999641180038452)
# ('Racing', 0.9999638795852661)
# ('Adventure', 0.9999621510505676)
# ('Role-Playing', 0.9999605417251587)
# ('Simulation', 0.9999598264694214)
# ('Shooter', 0.9999552965164185)
# ('Misc', 0.9999549984931946)
# ('Platform', 0.9999474883079529)
# ('Strategy', 0.9999400973320007)
# ('Puzzle', 0.9999264478683472)
# C:\Users\EQUIPO\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# [(2929, 'Pikmin 2'),
#  (813, 'Dark Souls III'),
#  (2740, 'Need for Speed: Most Wanted'),
#  (683, 'Company of Heroes 2'),
#  (4434, 'WWE All Stars'),
#  (1635, "Greg Hastings' Tournament Paintball"),
#  (87, 'Age of Mythology: The Titans'),
#  (4597, 'Worms: Open Warfare 2'),
#  (1504, 'G-Force'),
#  (1649, 'Guild Wars 2'),
#  (3159, 'Resident Evil 4'),
#  (217, "Assassin's Creed"),
#  (1829, 'IL-2 Sturmovik: Birds of Prey'),
#  (4129, 'The Urbz: Sims in the City'),
#  (2046, 'LEGO Marvel Super Heroes'),
#  (1590, 'GoldenEye: Rogue Agent'),
#  (2078, 'Lego Batman 3: Beyond Gotham'),
#  (141, 'Angry Birds Star Wars'),
#  (4562, 'World Soccer Winning Eleven 8 International'),
#  (1717, 'Harry Potter and the Half-Blood Prince')]
